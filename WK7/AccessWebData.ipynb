# %% [markdown]
# # Send HTTP Requests in Python

# %% [markdown]
# ## Use the socket library

# %%
import socket

# %%
mysocket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysocket.connect(('www.ufl.edu',80))

# %%
mysocket.send('GET /index.html HTTP/1.0\r\nHost: www.ufl.edu\r\n\r\n')
# Out:
# 47

# %%
while True:
    data = mysocket.recv(512)  #get 512 characters each time
    if (len(data)<1):
        break
    print data
mysocket.close()
# Out:
# HTTP/1.1 200 OK
# Date: Mon, 26 Feb 2018 15:44:03 GMT
# Server: Apache
# Accept-Ranges: bytes
# Cache-Control: max-age=60
# Expires: Mon, 26 Feb 2018 15:45:03 GMT
# Vary: Accept-Encoding
# X-UFL-RequestURI: /index.html
# X-UFL-RealServer: 128.227.9.98
# X-UFL-VirtServer: www.ufl.edu
# Connection: keep-alive, close
# Content-Length: 30086
# Content-Type: text/html; charset=UTF-8
#
# <!DOCTYPE html>
# <html lang="en" class="no-js">
# <head>
#   <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getT
# ime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NZ4MS8Q');</script>
#
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width,initial-scale=1">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge" />
# 	<title>University of Florida</title>
# 	<link rel="stylesheet" href="/media/templ
# ates/uf2015/css/style.css">
#
#
#
# 	<link rel="icon" href="/media/templates/uf2015/img/favicon.ico" >
# 	<link rel="apple-touch-icon" href="/media/templates/uf2015/img/favicon-180.png">
# 	<meta name="msapplication-TileColor" content="#00529b">
# 	<meta name="msapplication-TileImage" content="/media/templates/uf2015/img/favicon-144.png">
# 	<script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s
# .getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create', 'UA-3703196-1', 'auto');ga('send', 'pageview');</script>
#
# </head>
#
# <body class="loading home" data-page-layout="homepage">
#   <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NZ4MS8Q" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#   <h1 class="visuallyhidden">University of Florida</h1
# >
#   <a href="#main" id="skip-link" class="visuallyhidden focusable">Skip to main content</a>
#   <div class="header">
#     <a href="http://www.ufl.edu/" class="logo"><img src="/media/templates/uf2015/img/logo-uf.svg"
#      alt="logo-uf" style="width : -1px; height : -1px;     "
#     class="" /></a>
#
#     <div class="menu-wrap">
#       <div class="main-menu-wrap">
#
#       	<ul>
#       	<li>
#   <a href="/about/" class="main-menu-link"><span>About</span> <span class="icon-svg icon-caret"><svg><u
# se xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/about.jpg" alt="About Image" class="img-full">
#     </div>
#     <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Administration" href="/about/administration/">Administration</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Maps &amp; Directions" href="/ab
# out/maps-directions/">Maps &amp; Directions</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Campus Tours" href="/about/campus-tours/">Campus Tours</a></li>
# <li><a href="http://publicrecords.ufl.edu/">Public Records</a></li>
# </ul>
#     <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; University Facts" href="/about/university-facts/">University Facts</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Hist
# ory" href="/about/history/">History</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Offices &amp; Services" href="/about/offices-services/">Offices &amp; Services</a></li>
# <li><a href="http://www.ufl.edu/about/service-outreach/">Service &amp; Outreach</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/academics/" class="main-menu-link"><span>Academics</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></sv
# g></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/academics.jpg" alt="Academics Image" class="img-full">
#     </div>
#     <ul>
# <li><a href="/academics/colleges/">Colleges</a></li>
# <li><a href="/academics/programs/">Programs</a></li>
# <li><a href="/academics/courses/">Courses</a></li>
# <li><a href="/academics/online-learning/">Online Learning</a></li>
# </ul>
#     <ul>
# <li><a href="https://catalog.ufl.edu/ugrad/current/Pages/certificates.aspx">Certif
# icates</a></li>
# <li><a href="http://pd.dce.ufl.edu/program-finder">Continuing Education</a></li>
# <li><a href="/academics/libraries/">Libraries</a></li>
# <li><a href="/academics/resources/">Resources</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/admissions/" class="main-menu-link"><span>Admissions</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/medi
# a/wwwufledu/images/nav/admissions.jpg" alt="Admissions Image" class="img-full">
#     </div>
#     <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Undergraduate" href="/admissions/undergraduate/">Undergraduate</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Graduate" href="/admissions/graduate/">Graduate</a></li>
# <li><a href="http://www.admissions.ufl.edu/prospectiveinternational.html">International</a></li>
# </ul>
#     <ul>
# <li>
# <a href="http://www.ufl.edu/academics/online-learning/">Online Learning</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Professional" href="/admissions/professional/">Professional</a></li>
# <li><a href="http://www.sfa.ufl.edu/">Financial Aid</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/student-life/" class="main-menu-link"><span>Student Life</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></sv
# g></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/campuslife.jpg" alt="Student Life Image" class="img-full">
#     </div>
#     <ul>
# <li><a href="/student-life/arts/">Arts</a></li>
# <li><a href="/student-life/recreation-fitness/">Recreation &amp; Fitness</a></li>
# <li><a href="/student-life/cultural-opportunities/">Cultural Opportunities</a></li>
# <li><a href="/student-life/involvement/">Involvement</a></li>
# </ul>
#     <ul>
# <li><a href="/student-life
# /health-safety/">Health &amp; Safety</a></li>
# <li><a href="/student-life/career-exploration/">Career Exploration</a></li>
# <li><a href="/student-life/housing/">Housing</a></li>
# <li><a href="/student-life/success-services/">Success Services</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/research/" class="main-menu-link"><span>Research</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div cla
# ss="col-md-4">
#       <img src="/media/wwwufledu/images/nav/research.jpg" alt="Research Image" class="img-full">
#     </div>
#     <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Centers &amp; Institutes" href="/research/centers-institutes/">Centers &amp; Institutes</a></li>
# <li><a title="Office of Research" href="http://research.ufl.edu/">Office of Research</a></li>
# </ul>
#     <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Technology
#  Licensing" href="/research/technology-licensing/">Technology Licensing</a></li>
# <li><a href="http://research.ufl.edu/faculty-and-staff/finding-funding.html">Research Funding</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/athletics/" class="main-menu-link"><span>Athletics</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/al
# thletics.jpg" alt="Athletics Image" class="img-full">
#     </div>
#     <ul>
# <li><a href="http://www.floridagators.com">Florida Gators</a></li>
# <li><a href="http://floridagators.com/calendar.aspx">Schedule</a></li>
# </ul>
#     <ul>
# <li><a href="http://floridagators.com/sports/2015/12/10/_tickets_.aspx">Tickets</a></li>
# <li><a href="http://floridagators.com/facilities/">Facilities</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/alumni/" class="main-menu-link"><span>Alumni</span> <span class="icon-svg icon-car
# et"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/alumni.jpg" alt="Alumni Image" class="img-full">
#     </div>
#     <ul>
# <li><a href="http://www.ufalumni.ufl.edu">Alumni Association</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/network/gatorclubs">Gator Clubs®</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/membership/join-the-ufaa">Membership</a>
# </li>
# <li><a href="http://connect.ufalumni.ufl.edu/events/signature-events">Reunions</a></li>
# </ul>
#     <ul>
# <li><a href="https://www.uff.ufl.edu/">Alumni Giving</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Maps &amp; Directions" href="/about/maps-directions/">Maps &amp; Directions</a></li>
# <li><a href="http://virtualtour.ufl.edu/">Virtual Tour</a></li>
# </ul>
#   </div>
# </li>
#         </ul>
#       </div>
#       <div class="aux-menu-wrap">
#           <ul class="aux-n
# av">
# <li><a href="http://news.ufl.edu">News</a></li>
# <li><a href="http://calendar.ufl.edu">Calendar</a></li>
# <li><a href="/about/offices-services/">Offices &amp; Services</a></li>
# <li><a href="https://directory.ufl.edu">Directory</a></li>
# <li><a href="http://uff.ufl.edu/Giving/WhyGive.asp">Giving</a></li>
# <li><a href="http://ufhealth.org">UF Health</a></li>
# <li><a href="http://ifas.ufl.edu">UF/IFAS</a></li>
# <li><a href="http://assistive.usablenet.com/tt/referrer">Text-only</a></li>
# </ul>
#           <div cla
# ss="audience-nav-wrap"><a href="#" class="cur-audience">Welcome to UF</a><span class="arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-down"></use></svg></span><ul>
# <li><a href="/students/">Current Students</a></li>
# <li><a href="/visitors/">Family &amp; Visitors</a></li>
# <li><a href="/staff/">Faculty &amp; Staff</a></li>
# </ul></div>
#       </div>
#       <a href="#" class="btn-show-aux">
#               <span class="icon-svg icon-menu">
#               <svg>
#
#   <use xlink:href="/media/templates/uf2015/img/spritemap.svg#menu"></use>
#               </svg>
#           </span>
#               <span class="icon-svg icon-close">
#               <svg>
#               <use xlink:href="/media/templates/uf2015/img/spritemap.svg#close"></use>
#               </svg>
#           </span>
#         </a>
#       <form action="https://search.ufl.edu/search" method="get" class="search-wrap">
#           <input type="hidden" name="source" value="web">
#
#           <label for="quer
# y_desktop" class="visuallyhidden">Search UF</label>
#           <input type="text" id="query_desktop" name="query">
#           <label for="submit_desktop" class="visuallyhidden">Submit</label>
#           <button type="submit" id="submit_desktop" name="submit" class="btn-search">
#               <span class="icon-svg">
#               <svg>
#                   <use xlink:href="/media/templates/uf2015/img/spritemap.svg#search"></use>
#               </svg>
#             </span>
#           </button>
#         </form>
#
#     </div>
#
#     <div class="mobile-dropdown-wrap"></div>
#
#       <form action="https://search.ufl.edu/search" method="get" class="search-wrap mobile">
#           <input type="hidden" name="source" value="web">
#
#           <label for="query_mobile" class="visuallyhidden">Search UF</label>
#           <input type="text" id="query_mobile" name="query">
#           <label for="submit_mobile" class="visuallyhidden">Submit</label>
#       <button type="submit" id="submit_mobile" class="btn-search"
# >
#           <span class="icon-svg">
#           <svg>
#               <use xlink:href="/media/templates/uf2015/img/spritemap.svg#search"></use>
#           </svg>
#         </span>
#       </button>
#     </form>
#
#     <a href="#" class="btn-menu">
#           <span class="icon-svg icon-menu">
#           <svg>
#           <use xlink:href="/media/templates/uf2015/img/spritemap.svg#menu"></use>
#           </svg>
#       </span>
#           <span class="icon-svg icon-close">
#           <svg>
#           <use xlink:hr
# ef="/media/templates/uf2015/img/spritemap.svg#close"></use>
#           </svg>
#       </span>
#     </a>
#   </div>
#
#   <div id="main">
#     <div class="home-section">
#       <div class="homepage-wrapper"><div class="featured-story-wrap">
# 	<div class="featured-story-img-wrap">
# 		<div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2018/02/NursingTwins1.jpg)"></div>
# <div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2017/12/scent-hero.jpg)"
# ></div>
# <div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2017/12/Becoming-Visible-3---hero.jpg)"></div>
#
# 	</div>
# </div>
# <div class="homepage-stat-wrap">
# 	<div class="container">
# 		<div class="row">
# 			<div class="col-sm-12">
# 				<div class="featured-story-content-wrap-wrap">
# 					<div class="featured-story-content-wrap col-md-6 col-md-offset-1">
# 						<div class="featured-story article-459925">
# 	<h2>A life-changing opportunity </h2><a href="https://www.uff.ufl
# .edu/your-impact/twin-nurses-one-life-changing-opportunity/" class="read-more" aria-label="A life-changing opportunity">Read more</a>
#
# 	<!--
# 	<h2>A life-changing opportunity </h2> <a href="/articles/2018/02/uff-nurse-twins.html" class="read-more" aria-label="A life-changing opportunity">Read more</a>
# 	-->
#
# 	<!--
#     <div class="category-tag"></div>
#     -->
#     <div class="category-tag">Go Greater</div>
# </div><div class="featured-story article-448513">
# 	<h2>Scents and sensibility </h2><a href="h
# ttps://spark.adobe.com/page/Y9NmZQ8B6vPlq/" class="read-more" aria-label="Scents and sensibility">Read more</a>
#
# 	<!--
# 	<h2>Scents and sensibility </h2> <a href="/articles/2018/01/scents-and-sensibility.html" class="read-more" aria-label="Scents and sensibility">Read more</a>
# 	-->
#
# 	<!--
#     <div class="category-tag"></div>
#     -->
#     <div class="category-tag">Neuroscience</div>
# </div><div class="featured-story article-447032">
# 	<h2>Becoming Visible Part 3 </h2><a href="https://spark.adobe.com
# /page/TzDTglCxMpEW2/" class="read-more" aria-label="Becoming Visible Part 3">Read more</a>
#
# 	<!--
# 	<h2>Becoming Visible Part 3 </h2> <a href="/articles/2017/12/women-in-science-series---part-3.html" class="read-more" aria-label="Becoming Visible Part 3">Read more</a>
# 	-->
#
# 	<!--
#     <div class="category-tag"></div>
#     -->
#     <div class="category-tag">Women in Science Series</div>
# </div>
# 					</div>
# 				</div>
#
# 				<div class="stat-wrap one in-right randomized" data-position="one">
# 					<d
# iv class="stat">
#   <h2>70</h2>
# </div>
# <div class="info">
#   <div class="info-copy">
#     <p>70% of UF undergraduates secure employment or plan employment in the state of Florida.</p>
#   </div>
# </div>
# 				</div>
# 				<div class="big-stat-wrap one big-stat-img gradient-bg content-462424" style="background-image: url(/media/newsufledu/images/2018/02/2-14-18_Torch_Award_Jeremy1-1000x1000.jpg)" >
# 	<div class="big-stat-copy">
#
#           <a href="https://www.eng.ufl.edu/newengineer/cise/jeremy-waisome-ph-d
# -honored-nsbe-golden-torch-award/">
#           <!--
#           <a href="/articles/2018/02/torch-award.html">
#           -->
#           <h2>UF postdoctoral associate receives the Golden Torch Award</h2>
#
#           <!--
#
#           -->
#
#           <span class="read-more">Read more</span>
#         </a>
# 	</div>
# 	<!--
#     <div class="category-tag"></div>
#     -->
#     <div class="category-tag">Awards</div>
# </div>
# 				<div class="stat-wrap two in-bottom randomized" dat
# a-position="two">
# 					<div class="stat">
#   <h2>34</h2>
# </div>
# <div class="info">
#   <div class="info-copy">
#     <p>Number of academic departments at UF that offer at least one sustainability-focused or related course.</p>
#   </div>
# </div>
# 				</div>
# 				<div class="big-stat-wrap two big-stat-img gradient-bg content-462426" style="background-image: url(/media/newsufledu/images/2018/02/2-15-18_Gator_Day-1000x1000.jpg)" >
# 	<div class="big-stat-copy">
#
#           <a href="https://www.facebook.com/ufl
# orida/videos/10155353053624632/?hc_ref=ARSnd1CMKlKVUJVlPL6FuIb7XpnUnS-ibIuafuioRccSS8i1SNMonMyIE4ww22-2CRU">
#           <!--
#           <a href="/articles/2018/02/president-fuchs-at-gator-day.html">
#           -->
#           <h2>Live with President Fuchs at Gator Day</h2>
#
#           <!--
#
#           -->
#
#           <span class="read-more">Read more</span>
#         </a>
# 	</div>
#
#     <div class="category-tag">Social Media</div>
#
#
# </div>
# 				<div class="b
# ig-stat-wrap three big-stat-img gradient-bg content-464059" style="background-image: url(/media/newsufledu/images/generic/2015-09-25_Classroom-2-2.jpg)" >
# 	<div class="big-stat-copy">
#
#           <a href="http://news.ufl.edu/articles/2018/02/university-of-florida-launches-nations-first-center-for-public-interest-communications.php">
#           <!--
#           <a href="/articles/2018/02/public-interest-communications.html">
#           -->
#           <h2>University of Florida launches nation
# ’s first center for public interest communications</h2>
#
#           <!--
#
#           -->
#
#           <span class="read-more">Read more</span>
#         </a>
# 	</div>
#
#     <div class="category-tag">Global Impact</div>
#
#
# </div>
# 				<div class="big-stat-wrap four big-stat-img gradient-bg content-464109" style="background-image: url(/media/newsufledu/images/2018/02/telescope.jpg)" >
# 	<div class="big-stat-copy">
#
#           <a href="http://news.ufl.edu/articles/2018/02/uf
# -built-instrument-provides-new-look-at-supermassive-black-holes-magnetic-field.php">
#           <!--
#           <a href="/articles/2018/02/black-holes-magnetic-field.html">
#           -->
#           <h2>UF-built instrument provides new look at supermassive black hole's magnetic field</h2>
#
#           <!--
#
#           -->
#
#           <span class="read-more">Read more</span>
#         </a>
# 	</div>
#
#     <div class="category-tag">Research</div>
#
#
# </div>
# 			<
# /div>
# 		</div>
# 	</div>
# </div><div class="breaker" style="background-image: url(/media/wwwufledu/images/bg-breaker.jpg);" data-content="354081">
# 	<div class="container">
# 		<div class="row">
# 			<div class="col-sm-8 col-sm-offset-2">
#
# 				<h2>WANT TO BE A GATOR?</h2>
# 				<p>Whatever you’ve got your sights set on, that’s merely the beginning. As a Gator you’ll learn to see beyond the horizon. We measure success not in individual achievement, but where you go from there. Because when
# reaching your goals is just the starting point, there’s no end to what Gators can accomplish.</p>
# 				<p><a href="http://www.admissions.ufl.edu/apply/freshman/ " class="btn btn--white" aria-label="WANT TO BE A GATOR?">Learn More <span class="arw-right icon-svg"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span></a></p>
# 			</div>
# 		</div>
# 	</div>
# </div><div class="feature-bio-wrap hor-scroll-wrap" id="bio_257698" da
# ta-bio-affiliation="all">
# 	<div class="container">
# 		<div class="feature-bios">
# 			<div class="bio-wrap">
# 				<div class="bio hor-scroll-el">
# 					<div class="bio-img" style="background-image: url();"></div>
# 					<div class="copy-wrap">
# 						<h2></h2>
# 						<h3></h3>
# 						<p></p>
# 						<span class="category-tag orange"></span>
# 						<span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# 					</div>
# 				</div>
#
# 				<div class="bio hor-scroll-el">
# 					<div class="bio-img" style="background-image: url();"></div>
# 					<div class="copy-wrap">
# 					    <h2></h2>
# 					    <h3></h3>
# 					    <p></p>
# 					    <span class="category-tag orange"></span>
# 					    <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# 					</div>
# 				</div>
# 				<div class="bio hor-scroll-el">
# 					<div class="bio-img" style="background-image: url()
# ;"></div>
# 					<div class="copy-wrap">
# 					    <h2></h2>
# 					    <h3></h3>
# 					    <p></p>
# 					    <span class="category-tag orange"></span>
# 					    <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="feature-bio-copy-wrap">
# 				<h2></h2>
# 				<h3></h3>
# 				<p></p>
# 				<span class="category-tag orange"></span>
# 				<span class="btn-circle arw-right icon-svg
# "><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# 			</div>
# 		</div>
# 	</div>
# </div><div class="breaker" style="background-image: url(/media/wwwufledu/images/go_greater.jpg);" data-content="253749">
# 	<div class="container">
# 		<div class="row">
# 			<div class="col-sm-8 col-sm-offset-2">
#
# 				<h2>TOGETHER, WE GO GREATER</h2>
# 				<p>We are not content to rest. We aspire to solve grand challenges, and in doing so, to propel UF to the very top t
# ier of public universities.
# <br />Our Go Greater campaign is an investment not only in the future of our state, nation and world,
# <br />but also in YOU.
# <br /></p>
# 				<p><a href="https://www.uff.ufl.edu/gogreater/" class="btn btn--white" aria-label="TOGETHER, WE GO GREATER">Learn More <span class="arw-right icon-svg"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span></a></p>
# 			</div>
# 		</div>
# 	</div>
# </div><!-- /wo
# rkplace-domain-verification.html -->              <div class="footer-wrap">
#
#                   <div class="footer-top">
#   <div class="container">
#     <div class="row">
#       <div class="col-sm-12">
#         <ul class="footer-audience-nav">
#           <li><a href="http://admissions.ufl.edu/">Apply</a></li>
#           <li><a href="http://virtualtour.ufl.edu/">Visit</a></li>
#           <li><a href="https://jobs.ufl.edu/">Jobs</a></li>
#           <li><a href="http://questions.ufl.edu/">Ask UF
# </a></li>
#         </ul>
#       </div>
#     </div>
#   </div>
# </div>
#
#                   <div class="footer-bottom">
#                       <div class="container">
#                           <div class="row">
#
#                               <div class="col-md-4 col-md-push-8 footer-contact-wrap">
#                                 <a href="http://www.ufl.edu" class="footer-logo icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#florida-logo-full"></use></sv
# g><span class="visuallyhidden">University of Florida</span></a>
#                                   <ul class="social-nav">
#   <li><a href="http://www.facebook.com/uflorida/" class="btn-circle icon-svg icon-facebook"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#facebook"></use></svg><span class="visuallyhidden">Facebook</span></a></li>
#   <li><a href="https://twitter.com/UF/" class="btn-circle icon-svg icon-twitter"><svg><use xmlns:xlink="http://w
# ww.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#twitter"></use></svg><span class="visuallyhidden">Twitter</span></a></li>
#   <li><a href="https://instagram.com/uflorida/" class="btn-circle icon-svg icon-instagram"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#instagram"></use></svg><span class="visuallyhidden">Instagram</span></a></li>
#   <li><a href="http://www.youtube.com/user/universityofflorida/" class="btn-circle i
# con-svg icon-youtube"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#youtube"></use></svg><span class="visuallyhidden">YouTube</span></a></li>
# </ul>
#                                   <p class="address">University of Florida<br>Gainesville, FL 32611<br><span class="ufoperator">UF Operator: (352) 392-3261</span><br><a href="//assistive.usablenet.com/tt/referrer">Website text-only version</a></p>
#                                   <hr style="margin:
#  20px 0;">
# <div><strong>UF Public Records</strong></div>
# <div><a href="http://publicrecords.ufl.edu/" target="_blank">http://publicrecords.ufl.edu/</a></div>
# <div>Contact: John Hines</div>
# <div>Records Custodian (FS 119.12)</div>
# <div>Email: <a href="mailto:pr-request@ufl.edu" target="_blank">pr-request@ufl.edu</a></div>
#                               </div>
#
#                               <div class="col-md-8 col-md-pull-4">
#   <div class="row">
#     <div class="col-md-4 col-sm-4 footer-menu
# ">
#       <h2>Resources <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
#       <ul>
# <li><a href="https://one.uf.edu/">ONE.UF</a></li>
# <li><a href="https://webmail.ufl.edu/">Webmail</a></li>
# <li><a href="https://my.ufl.edu/ps/signon.html">myUFL</a></li>
# <li><a href="https://lss.at.ufl.edu/">e-Learning</a></li>
# <li><a href="https://directory.ufl.edu/">Directory</a></li>
# </ul>
#     </div
# >
#     <div class="col-md-4 col-sm-4 footer-menu">
#       <h2>Campus <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
#       <ul>
# <li><a href="http://ufweather.org/">Weather</a></li>
# <li><a href="http://campusmap.ufl.edu/">Campus Map</a></li>
# <li><a href="http://virtualtour.ufl.edu/">Student Tours</a></li>
# <li><a href="https://catalog.ufl.edu/ugrad/current/Pages/dates-and-deadlines.asp
# x">Academic Calendar</a></li>
# <li><a href="http://calendar.ufl.edu/">Events</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; statements.ufl.edu" href="http://statements.ufl.edu">Statements</a></li>
# </ul>
#     </div>
#     <div class="col-md-4 col-sm-4 footer-menu">
#       <h2>Website <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
#       <ul>
# <li><a title="Home &raquo; ufl.edu &raqu
# o; www.ufl.edu &raquo; Websites" href="/websites/">Website Listing</a></li>
# <li><a href="http://accessibility.ufl.edu/">Accessibility</a></li>
# <li><a href="http://privacy.ufl.edu/privacystatement.html">Privacy Policy</a></li>
# <li><a href="http://regulations.ufl.edu/">Regulations</a></li>
# </ul>
#     </div>
#   </div>
# </div>
#
#                           </div>
#                       </div>
#                   </div>
#
#               </div>
# 			</div>
# 		</div>
# 	</div>
#   <script>
#
# var statsjson = '/stats/index.json';
# var biosjson = '/biographies/index.json';
# </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/velocity/1.2.2/velocity.min.js"></script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/velocity/1.2.2/velocity.ui.min.js"></script>
#   <script type="text/javascript" src="/media/templates/uf2015/js/plugins.js"></script>
#   <script type="text/javascript" src="/media/tem
# plates/uf2015/js/scripts.js"></script>
#
#
#
# <script>
# $(document).ready(function() {
#
#
# });
# </script>
# <script>
# $(document).ready(function() {
# 	displayUFAlert();
#
# 	$('a').click(function() {
# 		var href = $(this).attr('href');
# 		if (href.match(/^http/) && !href.match(document.domain)) {
# 			ga('send', 'event', 'Outbound Links', 'Click', href);
# 		}
# 		if (href.match(/\.(doc|docx|pdf|ppt|pptx|xls|xlsx|zip)$/)) {
# 			ga('send', 'event', 'Downloads', 'Click', href);
# 		}
# 	});
# 	$('.aux-nav a').click(function(
# ) {
# 		ga('send', 'event', 'Auxiliary Navigation', 'Click', $(this).attr('href'));
# 	});
# 	$('.main-menu-wrap a').click(function() {
# 		ga('send', 'event', 'Primary Navigation', 'Click', $(this).attr('href'));
# 	});
# 	$('.featured-story a.read-more').click(function() {
# 		ga('send', 'event', 'Featured Story', 'Click', $(this).attr('href'));
# 	});
# 	$('.big-stat-wrap h2 a').click(function() {
# 		ga('send', 'event', 'Secondary Story', 'Click', $(this).attr('href'));
# 	});
# 	$('.footer-menu a').click(function() {
# 		ga('se
# nd', 'event', 'Footer Menu', 'Click', $(this).attr('href'));
# 	});
# 	$('.home .featured-story.article-271180 .category-tag').text('Inauguration');
# 	$('.home .big-stat-wrap.content-271968 .category-tag').text('Commencement');
#
# 	$('a').each(function(){
# 		var link_text = $(this).text().toUpperCase().trim();
# 		if ( link_text == 'LEARN MORE' || link_text == 'READ MORE'){
# 			$(this).addClass('read-more');
# 			if ($(this).attr('aria-label') == undefined){
# 				var label = $(this).closest('div').children(':header')[0]
# .textContent;
# 				$(this).attr('aria-label', label);
# 			}
# 	    }
# 	});
#
# });
# </script>
#
# <style>
# .embed-responsive {
#     position: relative;
#     display: block;
#     height: 0;
#     padding: 0;
#     overflow: hidden;
# }
# .embed-responsive .embed-responsive-item, .embed-responsive iframe, .embed-responsive embed, .embed-responsive object, .embed-responsive video {
#     position: absolute;
#     top: 0;
#     left: 0;
#     bottom: 0;
#     height: 100%;
#     width: 100%;
#     border: 0;
# }
# .embed-responsive.embed-responsive-16b
# y9 {
#     padding-bottom: 56.25%}
# .embed-responsive.embed-responsive-4by3 {
#     padding-bottom: 75%}
# span.ufoperator { font-weight: bold; }
# </style>
#
# <!-- Host: 128.227.74.198 -->
# <!-- 11e06c425fe89aaad9f91d050f0d192a5e5c4946 -->
#
#
# </body>
# </html>

# %% [markdown]
# ## Use the urllib library

# %%
import urllib

# %%
fhand = urllib.urlopen('http://www.ufl.edu/index.html')

for line in fhand:
    print line.strip()
# Out:
# <!DOCTYPE html>
# <html lang="en" class="no-js">
# <head>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NZ4MS8Q');</script>
#
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width,initial-scale=1">
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <title>University of Florida</title>
# <link rel="stylesheet" href="/media/templates/uf2015/css/style.css">
#
#
#
# <link rel="icon" href="/media/templates/uf2015/img/favicon.ico" >
# <link rel="apple-touch-icon" href="/media/templates/uf2015/img/favicon-180.png">
# <meta name="msapplication-TileColor" content="#00529b">
# <meta name="msapplication-TileImage" content="/media/templates/uf2015/img/favicon-144.png">
# <script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create', 'UA-3703196-1', 'auto');ga('send', 'pageview');</script>
#
# </head>
#
# <body class="loading home" data-page-layout="homepage">
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NZ4MS8Q" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <h1 class="visuallyhidden">University of Florida</h1>
# <a href="#main" id="skip-link" class="visuallyhidden focusable">Skip to main content</a>
# <div class="header">
# <a href="http://www.ufl.edu/" class="logo"><img src="/media/templates/uf2015/img/logo-uf.svg"
# alt="logo-uf" style="width : -1px; height : -1px;     "
# class="" /></a>
#
# <div class="menu-wrap">
# <div class="main-menu-wrap">
#
# <ul>
# <li>
# <a href="/about/" class="main-menu-link"><span>About</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/about.jpg" alt="About Image" class="img-full">
# </div>
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Administration" href="/about/administration/">Administration</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Maps &amp; Directions" href="/about/maps-directions/">Maps &amp; Directions</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Campus Tours" href="/about/campus-tours/">Campus Tours</a></li>
# <li><a href="http://publicrecords.ufl.edu/">Public Records</a></li>
# </ul>
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; University Facts" href="/about/university-facts/">University Facts</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; History" href="/about/history/">History</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Offices &amp; Services" href="/about/offices-services/">Offices &amp; Services</a></li>
# <li><a href="http://www.ufl.edu/about/service-outreach/">Service &amp; Outreach</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/academics/" class="main-menu-link"><span>Academics</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/academics.jpg" alt="Academics Image" class="img-full">
# </div>
# <ul>
# <li><a href="/academics/colleges/">Colleges</a></li>
# <li><a href="/academics/programs/">Programs</a></li>
# <li><a href="/academics/courses/">Courses</a></li>
# <li><a href="/academics/online-learning/">Online Learning</a></li>
# </ul>
# <ul>
# <li><a href="https://catalog.ufl.edu/ugrad/current/Pages/certificates.aspx">Certificates</a></li>
# <li><a href="http://pd.dce.ufl.edu/program-finder">Continuing Education</a></li>
# <li><a href="/academics/libraries/">Libraries</a></li>
# <li><a href="/academics/resources/">Resources</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/admissions/" class="main-menu-link"><span>Admissions</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/admissions.jpg" alt="Admissions Image" class="img-full">
# </div>
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Undergraduate" href="/admissions/undergraduate/">Undergraduate</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Graduate" href="/admissions/graduate/">Graduate</a></li>
# <li><a href="http://www.admissions.ufl.edu/prospectiveinternational.html">International</a></li>
# </ul>
# <ul>
# <li><a href="http://www.ufl.edu/academics/online-learning/">Online Learning</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Professional" href="/admissions/professional/">Professional</a></li>
# <li><a href="http://www.sfa.ufl.edu/">Financial Aid</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/student-life/" class="main-menu-link"><span>Student Life</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/campuslife.jpg" alt="Student Life Image" class="img-full">
# </div>
# <ul>
# <li><a href="/student-life/arts/">Arts</a></li>
# <li><a href="/student-life/recreation-fitness/">Recreation &amp; Fitness</a></li>
# <li><a href="/student-life/cultural-opportunities/">Cultural Opportunities</a></li>
# <li><a href="/student-life/involvement/">Involvement</a></li>
# </ul>
# <ul>
# <li><a href="/student-life/health-safety/">Health &amp; Safety</a></li>
# <li><a href="/student-life/career-exploration/">Career Exploration</a></li>
# <li><a href="/student-life/housing/">Housing</a></li>
# <li><a href="/student-life/success-services/">Success Services</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/research/" class="main-menu-link"><span>Research</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/research.jpg" alt="Research Image" class="img-full">
# </div>
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Centers &amp; Institutes" href="/research/centers-institutes/">Centers &amp; Institutes</a></li>
# <li><a title="Office of Research" href="http://research.ufl.edu/">Office of Research</a></li>
# </ul>
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Technology Licensing" href="/research/technology-licensing/">Technology Licensing</a></li>
# <li><a href="http://research.ufl.edu/faculty-and-staff/finding-funding.html">Research Funding</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/athletics/" class="main-menu-link"><span>Athletics</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/althletics.jpg" alt="Athletics Image" class="img-full">
# </div>
# <ul>
# <li><a href="http://www.floridagators.com">Florida Gators</a></li>
# <li><a href="http://floridagators.com/calendar.aspx">Schedule</a></li>
# </ul>
# <ul>
# <li><a href="http://floridagators.com/sports/2015/12/10/_tickets_.aspx">Tickets</a></li>
# <li><a href="http://floridagators.com/facilities/">Facilities</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/alumni/" class="main-menu-link"><span>Alumni</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/alumni.jpg" alt="Alumni Image" class="img-full">
# </div>
# <ul>
# <li><a href="http://www.ufalumni.ufl.edu">Alumni Association</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/network/gatorclubs">Gator Clubs®</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/membership/join-the-ufaa">Membership</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/events/signature-events">Reunions</a></li>
# </ul>
# <ul>
# <li><a href="https://www.uff.ufl.edu/">Alumni Giving</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; About &raquo; Maps &amp; Directions" href="/about/maps-directions/">Maps &amp; Directions</a></li>
# <li><a href="http://virtualtour.ufl.edu/">Virtual Tour</a></li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <div class="aux-menu-wrap">
# <ul class="aux-nav">
# <li><a href="http://news.ufl.edu">News</a></li>
# <li><a href="http://calendar.ufl.edu">Calendar</a></li>
# <li><a href="/about/offices-services/">Offices &amp; Services</a></li>
# <li><a href="https://directory.ufl.edu">Directory</a></li>
# <li><a href="http://uff.ufl.edu/Giving/WhyGive.asp">Giving</a></li>
# <li><a href="http://ufhealth.org">UF Health</a></li>
# <li><a href="http://ifas.ufl.edu">UF/IFAS</a></li>
# <li><a href="http://assistive.usablenet.com/tt/referrer">Text-only</a></li>
# </ul>
# <div class="audience-nav-wrap"><a href="#" class="cur-audience">Welcome to UF</a><span class="arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-down"></use></svg></span><ul>
# <li><a href="/students/">Current Students</a></li>
# <li><a href="/visitors/">Family &amp; Visitors</a></li>
# <li><a href="/staff/">Faculty &amp; Staff</a></li>
# </ul></div>
# </div>
# <a href="#" class="btn-show-aux">
# <span class="icon-svg icon-menu">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#menu"></use>
# </svg>
# </span>
# <span class="icon-svg icon-close">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#close"></use>
# </svg>
# </span>
# </a>
# <form action="https://search.ufl.edu/search" method="get" class="search-wrap">
# <input type="hidden" name="source" value="web">
#
# <label for="query_desktop" class="visuallyhidden">Search UF</label>
# <input type="text" id="query_desktop" name="query">
# <label for="submit_desktop" class="visuallyhidden">Submit</label>
# <button type="submit" id="submit_desktop" name="submit" class="btn-search">
# <span class="icon-svg">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#search"></use>
# </svg>
# </span>
# </button>
# </form>
# </div>
#
# <div class="mobile-dropdown-wrap"></div>
#
# <form action="https://search.ufl.edu/search" method="get" class="search-wrap mobile">
# <input type="hidden" name="source" value="web">
#
# <label for="query_mobile" class="visuallyhidden">Search UF</label>
# <input type="text" id="query_mobile" name="query">
# <label for="submit_mobile" class="visuallyhidden">Submit</label>
# <button type="submit" id="submit_mobile" class="btn-search">
# <span class="icon-svg">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#search"></use>
# </svg>
# </span>
# </button>
# </form>
#
# <a href="#" class="btn-menu">
# <span class="icon-svg icon-menu">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#menu"></use>
# </svg>
# </span>
# <span class="icon-svg icon-close">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#close"></use>
# </svg>
# </span>
# </a>
# </div>
#
# <div id="main">
# <div class="home-section">
# <div class="homepage-wrapper"><div class="featured-story-wrap">
# <div class="featured-story-img-wrap">
# <div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2018/02/NursingTwins1.jpg)"></div>
# <div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2017/12/scent-hero.jpg)"></div>
# <div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2017/12/Becoming-Visible-3---hero.jpg)"></div>
#
# </div>
# </div>
# <div class="homepage-stat-wrap">
# <div class="container">
# <div class="row">
# <div class="col-sm-12">
# <div class="featured-story-content-wrap-wrap">
# <div class="featured-story-content-wrap col-md-6 col-md-offset-1">
# <div class="featured-story article-459925">
# <h2>A life-changing opportunity </h2><a href="https://www.uff.ufl.edu/your-impact/twin-nurses-one-life-changing-opportunity/" class="read-more" aria-label="A life-changing opportunity">Read more</a>
#
# <!--
# <h2>A life-changing opportunity </h2> <a href="/articles/2018/02/uff-nurse-twins.html" class="read-more" aria-label="A life-changing opportunity">Read more</a>
# -->
#
# <!--
# <div class="category-tag"></div>
# -->
# <div class="category-tag">Go Greater</div>
# </div><div class="featured-story article-448513">
# <h2>Scents and sensibility </h2><a href="https://spark.adobe.com/page/Y9NmZQ8B6vPlq/" class="read-more" aria-label="Scents and sensibility">Read more</a>
#
# <!--
# <h2>Scents and sensibility </h2> <a href="/articles/2018/01/scents-and-sensibility.html" class="read-more" aria-label="Scents and sensibility">Read more</a>
# -->
#
# <!--
# <div class="category-tag"></div>
# -->
# <div class="category-tag">Neuroscience</div>
# </div><div class="featured-story article-447032">
# <h2>Becoming Visible Part 3 </h2><a href="https://spark.adobe.com/page/TzDTglCxMpEW2/" class="read-more" aria-label="Becoming Visible Part 3">Read more</a>
#
# <!--
# <h2>Becoming Visible Part 3 </h2> <a href="/articles/2017/12/women-in-science-series---part-3.html" class="read-more" aria-label="Becoming Visible Part 3">Read more</a>
# -->
#
# <!--
# <div class="category-tag"></div>
# -->
# <div class="category-tag">Women in Science Series</div>
# </div>
# </div>
# </div>
#
# <div class="stat-wrap one in-right randomized" data-position="one">
# <div class="stat">
# <h2>70</h2>
# </div>
# <div class="info">
# <div class="info-copy">
# <p>70% of UF undergraduates secure employment or plan employment in the state of Florida.</p>
# </div>
# </div>
# </div>
# <div class="big-stat-wrap one big-stat-img gradient-bg content-462424" style="background-image: url(/media/newsufledu/images/2018/02/2-14-18_Torch_Award_Jeremy1-1000x1000.jpg)" >
# <div class="big-stat-copy">
#
# <a href="https://www.eng.ufl.edu/newengineer/cise/jeremy-waisome-ph-d-honored-nsbe-golden-torch-award/">
# <!--
# <a href="/articles/2018/02/torch-award.html">
# -->
# <h2>UF postdoctoral associate receives the Golden Torch Award</h2>
#
# <!--
#
# -->
#
# <span class="read-more">Read more</span>
# </a>
# </div>
# <!--
# <div class="category-tag"></div>
# -->
# <div class="category-tag">Awards</div>
# </div>
# <div class="stat-wrap two in-bottom randomized" data-position="two">
# <div class="stat">
# <h2>34</h2>
# </div>
# <div class="info">
# <div class="info-copy">
# <p>Number of academic departments at UF that offer at least one sustainability-focused or related course.</p>
# </div>
# </div>
# </div>
# <div class="big-stat-wrap two big-stat-img gradient-bg content-462426" style="background-image: url(/media/newsufledu/images/2018/02/2-15-18_Gator_Day-1000x1000.jpg)" >
# <div class="big-stat-copy">
#
# <a href="https://www.facebook.com/uflorida/videos/10155353053624632/?hc_ref=ARSnd1CMKlKVUJVlPL6FuIb7XpnUnS-ibIuafuioRccSS8i1SNMonMyIE4ww22-2CRU">
# <!--
# <a href="/articles/2018/02/president-fuchs-at-gator-day.html">
# -->
# <h2>Live with President Fuchs at Gator Day</h2>
#
# <!--
#
# -->
#
# <span class="read-more">Read more</span>
# </a>
# </div>
#
# <div class="category-tag">Social Media</div>
#
#
# </div>
# <div class="big-stat-wrap three big-stat-img gradient-bg content-464059" style="background-image: url(/media/newsufledu/images/generic/2015-09-25_Classroom-2-2.jpg)" >
# <div class="big-stat-copy">
#
# <a href="http://news.ufl.edu/articles/2018/02/university-of-florida-launches-nations-first-center-for-public-interest-communications.php">
# <!--
# <a href="/articles/2018/02/public-interest-communications.html">
# -->
# <h2>University of Florida launches nation’s first center for public interest communications</h2>
#
# <!--
#
# -->
#
# <span class="read-more">Read more</span>
# </a>
# </div>
#
# <div class="category-tag">Global Impact</div>
#
#
# </div>
# <div class="big-stat-wrap four big-stat-img gradient-bg content-464109" style="background-image: url(/media/newsufledu/images/2018/02/telescope.jpg)" >
# <div class="big-stat-copy">
#
# <a href="http://news.ufl.edu/articles/2018/02/uf-built-instrument-provides-new-look-at-supermassive-black-holes-magnetic-field.php">
# <!--
# <a href="/articles/2018/02/black-holes-magnetic-field.html">
# -->
# <h2>UF-built instrument provides new look at supermassive black hole's magnetic field</h2>
#
# <!--
#
# -->
#
# <span class="read-more">Read more</span>
# </a>
# </div>
#
# <div class="category-tag">Research</div>
#
#
# </div>
# </div>
# </div>
# </div>
# </div><div class="breaker" style="background-image: url(/media/wwwufledu/images/bg-breaker.jpg);" data-content="354081">
# <div class="container">
# <div class="row">
# <div class="col-sm-8 col-sm-offset-2">
#
# <h2>WANT TO BE A GATOR?</h2>
# <p>Whatever you’ve got your sights set on, that’s merely the beginning. As a Gator you’ll learn to see beyond the horizon. We measure success not in individual achievement, but where you go from there. Because when reaching your goals is just the starting point, there’s no end to what Gators can accomplish.</p>
# <p><a href="http://www.admissions.ufl.edu/apply/freshman/ " class="btn btn--white" aria-label="WANT TO BE A GATOR?">Learn More <span class="arw-right icon-svg"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span></a></p>
# </div>
# </div>
# </div>
# </div><div class="feature-bio-wrap hor-scroll-wrap" id="bio_257698" data-bio-affiliation="all">
# <div class="container">
# <div class="feature-bios">
# <div class="bio-wrap">
# <div class="bio hor-scroll-el">
# <div class="bio-img" style="background-image: url();"></div>
# <div class="copy-wrap">
# <h2></h2>
# <h3></h3>
# <p></p>
# <span class="category-tag orange"></span>
# <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# </div>
# </div>
# <div class="bio hor-scroll-el">
# <div class="bio-img" style="background-image: url();"></div>
# <div class="copy-wrap">
# <h2></h2>
# <h3></h3>
# <p></p>
# <span class="category-tag orange"></span>
# <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# </div>
# </div>
# <div class="bio hor-scroll-el">
# <div class="bio-img" style="background-image: url();"></div>
# <div class="copy-wrap">
# <h2></h2>
# <h3></h3>
# <p></p>
# <span class="category-tag orange"></span>
# <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# </div>
# </div>
# </div>
# <div class="feature-bio-copy-wrap">
# <h2></h2>
# <h3></h3>
# <p></p>
# <span class="category-tag orange"></span>
# <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# </div>
# </div>
# </div>
# </div><div class="breaker" style="background-image: url(/media/wwwufledu/images/go_greater.jpg);" data-content="253749">
# <div class="container">
# <div class="row">
# <div class="col-sm-8 col-sm-offset-2">
#
# <h2>TOGETHER, WE GO GREATER</h2>
# <p>We are not content to rest. We aspire to solve grand challenges, and in doing so, to propel UF to the very top tier of public universities.
# <br />Our Go Greater campaign is an investment not only in the future of our state, nation and world,
# <br />but also in YOU.
# <br /></p>
# <p><a href="https://www.uff.ufl.edu/gogreater/" class="btn btn--white" aria-label="TOGETHER, WE GO GREATER">Learn More <span class="arw-right icon-svg"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span></a></p>
# </div>
# </div>
# </div>
# </div><!-- /workplace-domain-verification.html -->              <div class="footer-wrap">
#
# <div class="footer-top">
# <div class="container">
# <div class="row">
# <div class="col-sm-12">
# <ul class="footer-audience-nav">
# <li><a href="http://admissions.ufl.edu/">Apply</a></li>
# <li><a href="http://virtualtour.ufl.edu/">Visit</a></li>
# <li><a href="https://jobs.ufl.edu/">Jobs</a></li>
# <li><a href="http://questions.ufl.edu/">Ask UF</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
#
# <div class="footer-bottom">
# <div class="container">
# <div class="row">
#
# <div class="col-md-4 col-md-push-8 footer-contact-wrap">
# <a href="http://www.ufl.edu" class="footer-logo icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#florida-logo-full"></use></svg><span class="visuallyhidden">University of Florida</span></a>
# <ul class="social-nav">
# <li><a href="http://www.facebook.com/uflorida/" class="btn-circle icon-svg icon-facebook"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#facebook"></use></svg><span class="visuallyhidden">Facebook</span></a></li>
# <li><a href="https://twitter.com/UF/" class="btn-circle icon-svg icon-twitter"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#twitter"></use></svg><span class="visuallyhidden">Twitter</span></a></li>
# <li><a href="https://instagram.com/uflorida/" class="btn-circle icon-svg icon-instagram"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#instagram"></use></svg><span class="visuallyhidden">Instagram</span></a></li>
# <li><a href="http://www.youtube.com/user/universityofflorida/" class="btn-circle icon-svg icon-youtube"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#youtube"></use></svg><span class="visuallyhidden">YouTube</span></a></li>
# </ul>
# <p class="address">University of Florida<br>Gainesville, FL 32611<br><span class="ufoperator">UF Operator: (352) 392-3261</span><br><a href="//assistive.usablenet.com/tt/referrer">Website text-only version</a></p>
# <hr style="margin: 20px 0;">
# <div><strong>UF Public Records</strong></div>
# <div><a href="http://publicrecords.ufl.edu/" target="_blank">http://publicrecords.ufl.edu/</a></div>
# <div>Contact: John Hines</div>
# <div>Records Custodian (FS 119.12)</div>
# <div>Email: <a href="mailto:pr-request@ufl.edu" target="_blank">pr-request@ufl.edu</a></div>
# </div>
#
# <div class="col-md-8 col-md-pull-4">
# <div class="row">
# <div class="col-md-4 col-sm-4 footer-menu">
# <h2>Resources <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
# <ul>
# <li><a href="https://one.uf.edu/">ONE.UF</a></li>
# <li><a href="https://webmail.ufl.edu/">Webmail</a></li>
# <li><a href="https://my.ufl.edu/ps/signon.html">myUFL</a></li>
# <li><a href="https://lss.at.ufl.edu/">e-Learning</a></li>
# <li><a href="https://directory.ufl.edu/">Directory</a></li>
# </ul>
# </div>
# <div class="col-md-4 col-sm-4 footer-menu">
# <h2>Campus <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
# <ul>
# <li><a href="http://ufweather.org/">Weather</a></li>
# <li><a href="http://campusmap.ufl.edu/">Campus Map</a></li>
# <li><a href="http://virtualtour.ufl.edu/">Student Tours</a></li>
# <li><a href="https://catalog.ufl.edu/ugrad/current/Pages/dates-and-deadlines.aspx">Academic Calendar</a></li>
# <li><a href="http://calendar.ufl.edu/">Events</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; statements.ufl.edu" href="http://statements.ufl.edu">Statements</a></li>
# </ul>
# </div>
# <div class="col-md-4 col-sm-4 footer-menu">
# <h2>Website <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Websites" href="/websites/">Website Listing</a></li>
# <li><a href="http://accessibility.ufl.edu/">Accessibility</a></li>
# <li><a href="http://privacy.ufl.edu/privacystatement.html">Privacy Policy</a></li>
# <li><a href="http://regulations.ufl.edu/">Regulations</a></li>
# </ul>
# </div>
# </div>
# </div>
#
# </div>
# </div>
# </div>
#
# </div>
# </div>
# </div>
# </div>
# <script>
# var statsjson = '/stats/index.json';
# var biosjson = '/biographies/index.json';
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/velocity/1.2.2/velocity.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/velocity/1.2.2/velocity.ui.min.js"></script>
# <script type="text/javascript" src="/media/templates/uf2015/js/plugins.js"></script>
# <script type="text/javascript" src="/media/templates/uf2015/js/scripts.js"></script>
#
#
#
# <script>
# $(document).ready(function() {
#
#
# });
# </script>
# <script>
# $(document).ready(function() {
# displayUFAlert();
#
# $('a').click(function() {
# var href = $(this).attr('href');
# if (href.match(/^http/) && !href.match(document.domain)) {
# ga('send', 'event', 'Outbound Links', 'Click', href);
# }
# if (href.match(/\.(doc|docx|pdf|ppt|pptx|xls|xlsx|zip)$/)) {
# ga('send', 'event', 'Downloads', 'Click', href);
# }
# });
# $('.aux-nav a').click(function() {
# ga('send', 'event', 'Auxiliary Navigation', 'Click', $(this).attr('href'));
# });
# $('.main-menu-wrap a').click(function() {
# ga('send', 'event', 'Primary Navigation', 'Click', $(this).attr('href'));
# });
# $('.featured-story a.read-more').click(function() {
# ga('send', 'event', 'Featured Story', 'Click', $(this).attr('href'));
# });
# $('.big-stat-wrap h2 a').click(function() {
# ga('send', 'event', 'Secondary Story', 'Click', $(this).attr('href'));
# });
# $('.footer-menu a').click(function() {
# ga('send', 'event', 'Footer Menu', 'Click', $(this).attr('href'));
# });
# $('.home .featured-story.article-271180 .category-tag').text('Inauguration');
# $('.home .big-stat-wrap.content-271968 .category-tag').text('Commencement');
#
# $('a').each(function(){
# var link_text = $(this).text().toUpperCase().trim();
# if ( link_text == 'LEARN MORE' || link_text == 'READ MORE'){
# $(this).addClass('read-more');
# if ($(this).attr('aria-label') == undefined){
# var label = $(this).closest('div').children(':header')[0].textContent;
# $(this).attr('aria-label', label);
# }
# }
# });
#
# });
# </script>
#
# <style>
# .embed-responsive {
# position: relative;
# display: block;
# height: 0;
# padding: 0;
# overflow: hidden;
# }
# .embed-responsive .embed-responsive-item, .embed-responsive iframe, .embed-responsive embed, .embed-responsive object, .embed-responsive video {
# position: absolute;
# top: 0;
# left: 0;
# bottom: 0;
# height: 100%;
# width: 100%;
# border: 0;
# }
# .embed-responsive.embed-responsive-16by9 {
# padding-bottom: 56.25%}
# .embed-responsive.embed-responsive-4by3 {
# padding-bottom: 75%}
# span.ufoperator { font-weight: bold; }
# </style>
#
# <!-- Host: 128.227.74.198 -->
# <!-- 11e06c425fe89aaad9f91d050f0d192a5e5c4946 -->
#
#
# </body>
# </html>

# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## Get all links from a web page

# %%
import urllib
from bs4 import *

# %%
html = urllib.urlopen('http://www.ufl.edu/index.html').read()
soup = BeautifulSoup(html,"html5lib") #parsed html

# %%
tags = soup('a') #retrieve a list of the anchor tags
for tag in tags:
    print tag.get('href',None) #get the value of attribute 'href'
# Out:
# #main
# http://www.ufl.edu/
# /about/
# /about/administration/
# /about/maps-directions/
# /about/campus-tours/
# http://publicrecords.ufl.edu/
# /about/university-facts/
# /about/history/
# /about/offices-services/
# http://www.ufl.edu/about/service-outreach/
# /academics/
# /academics/colleges/
# /academics/programs/
# /academics/courses/
# /academics/online-learning/
# https://catalog.ufl.edu/ugrad/current/Pages/certificates.aspx
# http://pd.dce.ufl.edu/program-finder
# /academics/libraries/
# /academics/resources/
# /admissions/
# /admissions/undergraduate/
# /admissions/graduate/
# http://www.admissions.ufl.edu/prospectiveinternational.html
# http://www.ufl.edu/academics/online-learning/
# /admissions/professional/
# http://www.sfa.ufl.edu/
# /student-life/
# /student-life/arts/
# /student-life/recreation-fitness/
# /student-life/cultural-opportunities/
# /student-life/involvement/
# /student-life/health-safety/
# /student-life/career-exploration/
# /student-life/housing/
# /student-life/success-services/
# /research/
# /research/centers-institutes/
# http://research.ufl.edu/
# /research/technology-licensing/
# http://research.ufl.edu/faculty-and-staff/finding-funding.html
# /athletics/
# http://www.floridagators.com
# http://floridagators.com/calendar.aspx
# http://floridagators.com/sports/2015/12/10/_tickets_.aspx
# http://floridagators.com/facilities/
# /alumni/
# http://www.ufalumni.ufl.edu
# http://connect.ufalumni.ufl.edu/network/gatorclubs
# http://connect.ufalumni.ufl.edu/membership/join-the-ufaa
# http://connect.ufalumni.ufl.edu/events/signature-events
# https://www.uff.ufl.edu/
# /about/maps-directions/
# http://virtualtour.ufl.edu/
# http://news.ufl.edu
# http://calendar.ufl.edu
# /about/offices-services/
# https://directory.ufl.edu
# http://uff.ufl.edu/Giving/WhyGive.asp
# http://ufhealth.org
# http://ifas.ufl.edu
# http://assistive.usablenet.com/tt/referrer
# #
# /students/
# /visitors/
# /staff/
# #
# #
# https://www.uff.ufl.edu/your-impact/twin-nurses-one-life-changing-opportunity/
# https://spark.adobe.com/page/Y9NmZQ8B6vPlq/
# https://spark.adobe.com/page/TzDTglCxMpEW2/
# https://www.eng.ufl.edu/newengineer/cise/jeremy-waisome-ph-d-honored-nsbe-golden-torch-award/
# https://www.facebook.com/uflorida/videos/10155353053624632/?hc_ref=ARSnd1CMKlKVUJVlPL6FuIb7XpnUnS-ibIuafuioRccSS8i1SNMonMyIE4ww22-2CRU
# http://news.ufl.edu/articles/2018/02/university-of-florida-launches-nations-first-center-for-public-interest-communications.php
# http://news.ufl.edu/articles/2018/02/uf-built-instrument-provides-new-look-at-supermassive-black-holes-magnetic-field.php
# http://www.admissions.ufl.edu/apply/freshman/
# https://www.uff.ufl.edu/gogreater/
# http://admissions.ufl.edu/
# http://virtualtour.ufl.edu/
# https://jobs.ufl.edu/
# http://questions.ufl.edu/
# http://www.ufl.edu
# http://www.facebook.com/uflorida/
# https://twitter.com/UF/
# https://instagram.com/uflorida/
# http://www.youtube.com/user/universityofflorida/
# //assistive.usablenet.com/tt/referrer
# http://publicrecords.ufl.edu/
# mailto:pr-request@ufl.edu
# https://one.uf.edu/
# https://webmail.ufl.edu/
# https://my.ufl.edu/ps/signon.html
# https://lss.at.ufl.edu/
# https://directory.ufl.edu/
# http://ufweather.org/
# http://campusmap.ufl.edu/
# http://virtualtour.ufl.edu/
# https://catalog.ufl.edu/ugrad/current/Pages/dates-and-deadlines.aspx
# http://calendar.ufl.edu/
# http://statements.ufl.edu
# /websites/
# http://accessibility.ufl.edu/
# http://privacy.ufl.edu/privacystatement.html
# http://regulations.ufl.edu/

# %% [markdown]
# # API

# %% [markdown]
# ## Google Geocoding API

# %%
import urllib
import json

# %%
serviceurl = 'http://maps.googleapis.com/maps/api/geocode/json?'
address = 'Gainesville FL'

# %%
url = serviceurl + urllib.urlencode({'sensor':'false','address':address})
print 'Retrieving', url
uh = urllib.urlopen(url)
data = uh.read()
print 'Retrieved', len(data), 'characters'
# Out:
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Gainesville+FL
# Retrieved 1756 characters

# %%
try: js = json.loads(str(data))
except: js = None
if 'status' not in js or js['status'] != 'OK':
    print 'Fail to retrieve'
    print data
print json.dumps(js, indent=4)
# Out:
# {
#     "status": "OK",
#     "results": [
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 29.770553,
#                         "lng": -82.218976
#                     },
#                     "southwest": {
#                         "lat": 29.601988,
#                         "lng": -82.42051599999999
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.770553,
#                         "lng": -82.218976
#                     },
#                     "southwest": {
#                         "lat": 29.601988,
#                         "lng": -82.42051599999999
#                     }
#                 },
#                 "location": {
#                     "lat": 29.6516344,
#                     "lng": -82.32482619999999
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Gainesville",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Gainesville"
#                 },
#                 {
#                     "long_name": "Alachua County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Alachua County"
#                 },
#                 {
#                     "long_name": "Florida",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "FL"
#                 },
#                 {
#                     "long_name": "United States",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "US"
#                 }
#             ],
#             "place_id": "ChIJKyy_aSEg5ogRlo0QKF1554A",
#             "formatted_address": "Gainesville, FL, USA",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ]
# }

# %%
lat = js['results'][0]['geometry']['location']['lat']
lng = js['results'][0]['geometry']['location']['lng']
print 'lat',lat,'lng',lng
# Out:
# lat 29.6516344 lng -82.3248262

# %%
location = js['results'][0]['formatted_address']
print location
# Out:
# Gainesville, FL, USA

# %% [markdown]
# ## Twitter API

# %%
import urllib
from oauth import oauth

# %%
secrets = {
    "consumer_key" : "j...u",
    "consumer_secret" : "u...d",
    "token_key" : "8...L",
    "token_secret" : "f...V"
}
apiurl = 'https://api.twitter.com/1.1/statuses/user_timeline.json'
parameters = {'screen_name':'realDonaldTrump','count':'1'}

# %%
def augment(secrets,url,parameters):
    consumer = oauth.OAuthConsumer(secrets['consumer_key'],secrets['consumer_secret'])
    token = oauth.OAuthToken(secrets['token_key'],secrets['token_secret'])
    oauth_request = oauth.OAuthRequest.from_consumer_and_token(consumer,token=token, http_method='GET',http_url=url,parameters=parameters)
    oauth_request.sign_request(oauth.OAuthSignatureMethod_HMAC_SHA1(),consumer,token)
    return oauth_request.to_url()

# %%
url = augment(secrets,apiurl,parameters)

# %%
print url
# Out:
# https://api.twitter.com/1.1/statuses/user_timeline.json?count=1&oauth_version=1.0&oauth_token=835522116502044673-s1D23cl12aj4mV7zrIoR9MR6xhFsrNL&screen_name=realDonaldTrump&oauth_nonce=40440223&oauth_timestamp=1519316400&oauth_signature=Lg8pANGkdhZS9wVm5Moud9PY810%3D&oauth_consumer_key=jrzbw5dGqKVy2gYDZBTifeOtu&oauth_signature_method=HMAC-SHA1

# %%
connection = urllib.urlopen(url)

# %%
data = connection.read()

# %%
print data
# Out:
# [{"created_at":"Thu Feb 22 14:53:52 +0000 2018","id":966687491616059392,"id_str":"966687491616059392","text":"Will be meeting with Lawmakers today at 11:30 A.M. to discuss School Safety.  Next week it will be with our Nation\u2019\u2026 https:\/\/t.co\/USyL5x0ujR","truncated":true,"entities":{"hashtags":[],"symbols":[],"user_mentions":[],"urls":[{"url":"https:\/\/t.co\/USyL5x0ujR","expanded_url":"https:\/\/twitter.com\/i\/web\/status\/966687491616059392","display_url":"twitter.com\/i\/web\/status\/9\u2026","indices":[117,140]}]},"source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":25073877,"id_str":"25073877","name":"Donald J. Trump","screen_name":"realDonaldTrump","location":"Washington, DC","description":"45th President of the United States of America\ud83c\uddfa\ud83c\uddf8","url":"https:\/\/t.co\/OMxB0x7xC5","entities":{"url":{"urls":[{"url":"https:\/\/t.co\/OMxB0x7xC5","expanded_url":"http:\/\/www.Instagram.com\/realDonaldTrump","display_url":"Instagram.com\/realDonaldTrump","indices":[0,23]}]},"description":{"urls":[]}},"protected":false,"followers_count":48128141,"friends_count":45,"listed_count":85123,"created_at":"Wed Mar 18 13:46:38 +0000 2009","favourites_count":24,"utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":true,"verified":true,"statuses_count":36994,"lang":"en","contributors_enabled":false,"is_translator":false,"is_translation_enabled":true,"profile_background_color":"6D5C18","profile_background_image_url":"http:\/\/pbs.twimg.com\/profile_background_images\/530021613\/trump_scotland__43_of_70_cc.jpg","profile_background_image_url_https":"https:\/\/pbs.twimg.com\/profile_background_images\/530021613\/trump_scotland__43_of_70_cc.jpg","profile_background_tile":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/874276197357596672\/kUuht00m_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/874276197357596672\/kUuht00m_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/25073877\/1518843901","profile_link_color":"1B95E0","profile_sidebar_border_color":"BDDCAD","profile_sidebar_fill_color":"C5CEC0","profile_text_color":"333333","profile_use_background_image":true,"has_extended_profile":false,"default_profile":false,"default_profile_image":false,"following":false,"follow_request_sent":false,"notifications":false,"translator_type":"regular"},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":7566,"favorite_count":33302,"favorited":false,"retweeted":false,"lang":"en"}]

# %%
headers = connection.info().dict
print headers
# Out:
# {'content-length': '2800', 'x-rate-limit-reset': '1519317312', 'x-rate-limit-remaining': '899', 'x-xss-protection': '1; mode=block; report=https://twitter.com/i/xss_report', 'x-content-type-options': 'nosniff', 'x-connection-hash': '542bf8d794b780739bdc3f1ff95c576c', 'x-twitter-response-tags': 'BouncerCompliant', 'cache-control': 'no-cache, no-store, must-revalidate, pre-check=0, post-check=0', 'status': '200 OK', 'content-disposition': 'attachment; filename=json.json', 'set-cookie': 'personalization_id="v1_bYK6OKn9XadfIwp9ZEu4Kw=="; Expires=Sat, 22 Feb 2020 16:20:12 UTC; Path=/; Domain=.twitter.com, lang=en; Path=/, guest_id=v1%3A151931641202732606; Expires=Sat, 22 Feb 2020 16:20:12 UTC; Path=/; Domain=.twitter.com', 'expires': 'Tue, 31 Mar 1981 05:00:00 GMT', 'x-access-level': 'read-write', 'last-modified': 'Thu, 22 Feb 2018 16:20:12 GMT', 'pragma': 'no-cache', 'date': 'Thu, 22 Feb 2018 16:20:12 GMT', 'x-rate-limit-limit': '900', 'x-response-time': '73', 'x-transaction': '004df98f00ea056d', 'strict-transport-security': 'max-age=631138519', 'server': 'tsa_b', 'x-frame-options': 'SAMEORIGIN', 'content-type': 'application/json;charset=utf-8'}
