# %% [markdown]
# # Send HTTP Requests in Python

# %% [markdown]
# ## Use the socket library

# %%
import socket

# %%
mysocket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysocket.connect(('www.ufl.edu',80))

# %%
mysocket.send('GET http://www.ufl.edu/index.html \n\n')
# Out:
# 36

# %%
while True:
    data = mysocket.recv(512)  #get 512 characters each time
    if (len(data)<1):
        break
    print data
mysocket.close()
# Out:
# <!DOCTYPE html>
# <html lang="en" class="no-js">
# <head>
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width,initial-scale=1">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge" />
# 	<title>University of Florida</title>
# 	<link rel="stylesheet" href="/media/templates/uf2015/css/style.css">
#
#
#
# 	<link rel="icon" href="/media/templates/uf2015/img/favicon.ico" >
# 	<link rel="apple-touch-icon" href="/media/templates/uf2015/img/favicon-180.png">
# 	<meta name="msapplication-
# TileColor" content="#00529b">
# 	<meta name="msapplication-TileImage" content="/media/templates/uf2015/img/favicon-144.png">
# 	<script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create', 'UA-3703196-1', 'auto');ga('send', 'pageview');</script>
#
# </head>
#
# <body class="loading home">
#   <a href="#main" id="skip-link" class="visuallyhidden focusable">Skip to main content</a>
#   <div class="header">
#     <a href="http://www.ufl.edu/" class="logo"><img src="/media/templates/uf2015/img/logo-uf.svg"
#      alt="logo-uf" style="width : -1px; height : -1px;     "
#     class="" /></a>
#
#     <div class="menu-wrap">
#       <div class="main-menu-wrap">
#
#       	<ul>
#       	<li>
#   <a href="/about/" class="main-menu-link"><span>About</span> <s
# pan class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/about.jpg" alt="About Image" class="img-full">
#     </div>
#     <ul>
# <li><a href="/about/administration/">Administration</a></li>
# <li><a href="/about/maps-directions/">Maps &amp; Directions</a></li>
# <li><a href="/about/campus-tours/">Campus Tours</a></li>
# </ul>
#     <ul>
# <li><a href="/
# about/university-facts/">University Facts</a></li>
# <li><a href="/about/history/">History</a></li>
# <li><a href="/about/offices-services/">Offices &amp; Services</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/academics/" class="main-menu-link"><span>Academics</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/academics.jpg" al
# t="Academics Image" class="img-full">
#     </div>
#     <ul>
# <li><a href="/academics/colleges/">Colleges</a></li>
# <li><a href="/academics/programs/">Programs</a></li>
# <li><a href="/academics/courses/">Courses</a></li>
# <li><a href="/academics/online-learning/">Online Learning</a></li>
# </ul>
#     <ul>
# <li><a href="https://catalog.ufl.edu/ugrad/current/Pages/certificates.aspx">Certificates</a></li>
# <li><a href="http://pd.dce.ufl.edu/program-finder">Continuing Education</a></li>
# <li><a href="/academics/libraries
# /">Libraries</a></li>
# <li><a href="/academics/resources/">Resources</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/admissions/" class="main-menu-link"><span>Admissions</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/admissions.jpg" alt="Admissions Image" class="img-full">
#     </div>
#     <ul>
# <li><a title="Home &raquo; u
# fl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Undergraduate" href="/admissions/undergraduate/">Undergraduate</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Graduate" href="/admissions/graduate/">Graduate</a></li>
# <li><a href="http://www.admissions.ufl.edu/prospectiveinternational.html">International</a></li>
# </ul>
#     <ul>
# <li><a href="http://www.ufl.edu/academics/online-learning/">Online Learning</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.uf
# l.edu &raquo; Admissions &raquo; Professional" href="/admissions/professional/">Professional</a></li>
# <li><a href="http://www.sfa.ufl.edu/">Financial Aid</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/student-life/" class="main-menu-link"><span>Student Life</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/campuslife.jpg" a
# lt="Student Life Image" class="img-full">
#     </div>
#     <ul>
# <li><a href="/student-life/arts/">Arts</a></li>
# <li><a href="/student-life/recreation-fitness/">Recreation &amp; Fitness</a></li>
# <li><a href="/student-life/cultural-opportunities/">Cultural Opportunities</a></li>
# <li><a href="/student-life/involvement/">Involvement</a></li>
# </ul>
#     <ul>
# <li><a href="/student-life/health-safety/">Health &amp; Safety</a></li>
# <li><a href="/student-life/career-exploration/">Career Exploration</a></li>
# <li><a h
# ref="/student-life/housing/">Housing</a></li>
# <li><a href="/student-life/success-services/">Success Services</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/research/" class="main-menu-link"><span>Research</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/research.jpg" alt="Research Image" class="img-full">
#     </div>
#
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Centers &amp; Institutes" href="/research/centers-institutes/">Centers &amp; Institutes</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Undergraduate Research" href="/research/undergraduate-research/">Undergrad Research</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Graduate Research" href="/research/graduate-research/">Graduate Research</a><
# /li>
# <li><a title="Office of Research" href="http://research.ufl.edu/">Office of Research</a></li>
# </ul>
#     <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Technology Licensing" href="/research/technology-licensing/">Technology Licensing</a></li>
# <li><a href="http://research.ufl.edu/faculty-and-staff/finding-funding.html">Research Funding</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/athletics/" class="main-menu-link"><span>Athletics</span> <span class="icon-svg ico
# n-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/althletics.jpg" alt="Athletics Image" class="img-full">
#     </div>
#     <ul>
# <li><a href="http://www.floridagators.com">Florida Gators</a></li>
# <li><a href="http://floridagators.com/calendar.aspx">Schedule</a></li>
# </ul>
#     <ul>
# <li><a href="http://floridagators.com/sports/2015/12/10/_tickets_.aspx">Ticke
# ts</a></li>
# <li><a href="http://floridagators.com/facilities/">Facilities</a></li>
# </ul>
#   </div>
# </li><li>
#   <a href="/alumni/" class="main-menu-link"><span>Alumni</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
#   <div class="dropdown">
#     <div class="col-md-4">
#       <img src="/media/wwwufledu/images/nav/alumni.jpg" alt="Alumni Image" class="img-full">
#     </div>
#     <ul>
# <li><a href="http://www.ufalumni.ufl.e
# du">Alumni Association</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/network/gatorclubs">Gator Clubs&reg;</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/membership/join-the-ufaa">Membership</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/events/signature-events">Reunions</a></li>
# </ul>
#     <ul>
# <li><a href="https://www.uff.ufl.edu/">Giving</a></li>
# <li><a href="/about/maps-directions/">Maps &amp; Directions</a></li>
# <li><a href="http://virtualtour.ufl.edu/">Virtual Tour</a></li>
# </ul>
#
#   </div>
# </li>
#         </ul>
#       </div>
#       <div class="aux-menu-wrap">
#           <ul class="aux-nav">
# <li><a href="http://news.ufl.edu">News</a></li>
# <li><a href="http://calendar.ufl.edu">Calendar</a></li>
# <li><a href="/about/offices-services/">Offices &amp; Services</a></li>
# <li><a href="https://directory.ufl.edu">Directory</a></li>
# <li><a href="http://uff.ufl.edu/Giving/WhyGive.asp">Giving</a></li>
# <li><a href="http://ufhealth.org">UF Health</a></li>
# <li><a href="http://ifas.ufl.edu">UF/IFAS</a
# ></li>
# <li><a href="http://assistive.usablenet.com/tt/referrer">Text-only</a></li>
# </ul>
#           <div class="audience-nav-wrap"><a href="#" class="cur-audience">Welcome to UF</a><span class="arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-down"></use></svg></span><ul>
# <li><a href="/students/">Current Students</a></li>
# <li><a href="/visitors/">Family &amp; Visitors</a></li>
# <li><a href="/staff/">Faculty &amp; Staff</a></li>
# </ul></div>
#       </div>
#       <a href="
# #" class="btn-show-aux">
#               <span class="icon-svg icon-menu">
#               <svg>
#               <use xlink:href="/media/templates/uf2015/img/spritemap.svg#menu"></use>
#               </svg>
#           </span>
#               <span class="icon-svg icon-close">
#               <svg>
#               <use xlink:href="/media/templates/uf2015/img/spritemap.svg#close"></use>
#               </svg>
#           </span>
#         </a>
#       <form action="https://search.ufl.edu/search" method="get" class="sea
# rch-wrap">
#           <input type="hidden" name="source" value="web">
#
#           <label for="query_desktop" class="visuallyhidden">Search UF</label>
#           <input type="text" id="query_desktop" name="query">
#           <label for="submit_desktop" class="visuallyhidden">Submit</label>
#           <button type="submit" id="submit_desktop" name="submit" class="btn-search">
#               <span class="icon-svg">
#               <svg>
#                   <use xlink:href="/media/templates/uf2015/img/s
# pritemap.svg#search"></use>
#               </svg>
#             </span>
#           </button>
#         </form>
#     </div>
#
#     <div class="mobile-dropdown-wrap"></div>
#
#       <form action="https://search.ufl.edu/search" method="get" class="search-wrap mobile">
#           <input type="hidden" name="source" value="web">
#
#           <label for="query_mobile" class="visuallyhidden">Search UF</label>
#           <input type="text" id="query_mobile" name="query">
#           <label for="submit_mobi
# le" class="visuallyhidden">Submit</label>
#       <button type="submit" id="submit_mobile" class="btn-search">
#           <span class="icon-svg">
#           <svg>
#               <use xlink:href="/media/templates/uf2015/img/spritemap.svg#search"></use>
#           </svg>
#         </span>
#       </button>
#     </form>
#
#     <a href="#" class="btn-menu">
#           <span class="icon-svg icon-menu">
#           <svg>
#           <use xlink:href="/media/templates/uf2015/img/spritemap.svg#menu"></use>
#           <
# /svg>
#       </span>
#           <span class="icon-svg icon-close">
#           <svg>
#           <use xlink:href="/media/templates/uf2015/img/spritemap.svg#close"></use>
#           </svg>
#       </span>
#     </a>
#   </div>
#
#   <div id="main">
#     <div class="home-section">
#       <div class="homepage-wrapper"><div class="featured-story-wrap">
# 	<div class="featured-story-img-wrap">
# 		<div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2017/02/Bat-Banner---Homepage.gif)"><
# /div>
# <div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2017/02/theinstitutes_crop.jpg)"></div>
# <div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2017/02/fanara-hero.jpg)"></div>
#
# 	</div>
# </div>
# <div class="homepage-stat-wrap">
# 	<div class="container">
# 		<div class="row">
# 			<div class="col-sm-12">
# 				<div class="featured-story-content-wrap-wrap">
# 					<div class="featured-story-content-wrap col-md-6 col-md-offset-1">
# 						<
# div class="featured-story article-370148">
# 	<h2>UF’s bat village adds new barn <a href="https://ufnews.atavist.com/echo-relocation" class="read-more">Read more</a></h2>
#
# 	<!--
# 	<h2>UF’s bat village adds new barn <a href="/articles/2017/02/bat-village-primary-with-gif-banner.html" class="read-more">Read more</a></h2>
# 	-->
#
# 	<!--
#     <div class="category-tag"></div>
#     -->
#     <div class="category-tag">Campus wildlife</div>
# </div><div class="featured-story article-369190">
# 	<h2>Revitalizing
#  our roots <a href="https://social.shorthand.com/UFNews/3ycMiApTq6/revitalizing-our-roots" class="read-more">Read more</a></h2>
#
# 	<!--
# 	<h2>Revitalizing our roots <a href="/articles/2017/02/the-institutes-primary-from-shorthand-story.html" class="read-more">Read more</a></h2>
# 	-->
#
#
#     <div class="category-tag">Campus Life</div>
#
#
# </div><div class="featured-story article-367971">
# 	<h2>This MythBuster breaks stereotypes, too <a href="http://news.ufl.edu/articles/2017/02/mythbusters-con
# testant-brings-shows-lessons-to-water-treatment-work-.php" class="read-more">Read more</a></h2>
#
# 	<!--
# 	<h2>This MythBuster breaks stereotypes, too <a href="/articles/2017/02/this-mythbuster-breaks-stereotypes-too.html" class="read-more">Read more</a></h2>
# 	-->
#
# 	<!--
#     <div class="category-tag"></div>
#     -->
#     <div class="category-tag">Gators in the News</div>
# </div>
# 					</div>
# 				</div>
#
# 				<div class="stat-wrap one in-right randomized" data-position="one">
# 					<div class="stat">
#
#   <h2>70</h2>
# </div>
# <div class="info">
#   <div class="info-copy">
#     <p>70% of UF undergraduates secure employment or plan employment in the state of Florida.</p>
#   </div>
# </div>
# 				</div>
# 				<div class="big-stat-wrap one big-stat-img gradient-bg content-369191" style="background-image: url(/media/newsufledu/images/2017/02/SoldiersSquare.jpg)" >
# 	<div class="big-stat-copy">
# 		<h2><a href="http://news.ufl.edu/articles/2017/02/university-of-florida-partners-in-new-manufacturing-usa-institute.ph
# p" >Developing bones that won’t be rejected and more</a></h2>
# 		<!--
# 		<h2><a href="/articles/2017/02/developing-bones-that-wont-be-rejected-and-more.html">Developing bones that won’t be rejected and more</a></h2>
# 		-->
#
# 		<!--
# 		<p>Developing bones that won’t be rejected and more</p>
# 		-->
#
# 		<a href="http://news.ufl.edu/articles/2017/02/university-of-florida-partners-in-new-manufacturing-usa-institute.php" class="read-more">Read more</a>
# 		<!--
# 		<a href="/articles/2017/02/developing-bone
# s-that-wont-be-rejected-and-more.html" class="read-more">Read more</a>
# 		-->
# 	</div>
# 	<!--
#     <div class="category-tag"></div>
#     -->
#     <div class="category-tag">Biofabrication</div>
# </div>
# 				<div class="stat-wrap two in-bottom randomized" data-position="two">
# 					<div class="stat">
#   <h2>1,900</h2>
# </div>
# <div class="info">
#   <div class="info-copy">
#     <p>More than 1,900 All-America honors earned by Gator athletes.</p>
#   </div>
# </div>
# 				</div>
# 				<div class="big-stat-wrap two b
# ig-stat-img gradient-bg content-365238" style="background-image: url(/media/newsufledu/images/2017/01/FuchsTurlington.PNG)" >
# 	<div class="big-stat-copy">
# 		<h2><a href="https://www.facebook.com/uflorida/videos/1158827657559258/" >President Fuchs talks with students in Turlington</a></h2>
# 		<!--
# 		<h2><a href="/articles/2017/01/social---fuchs--turlington.html">President Fuchs talks with students in Turlington</a></h2>
# 		-->
#
# 		<!--
# 		<p>President Fuchs talks with students in Turlington</p>
# 		-->
#
#
# 		<a href="https://www.facebook.com/uflorida/videos/1158827657559258/" class="read-more">Read more</a>
# 		<!--
# 		<a href="/articles/2017/01/social---fuchs--turlington.html" class="read-more">Read more</a>
# 		-->
# 	</div>
#
#     <div class="category-tag">Social Media</div>
#
#
# </div>
# 				<div class="big-stat-wrap three big-stat-img gradient-bg content-369192" style="background-image: url(/media/newsufledu/images/2017/02/Tortoise.jpg)" >
# 	<div class="big-stat-copy">
# 		<h2><a href="http://news.u
# fl.edu/articles/2017/02/extinct-tortoise-yields-oldest-tropical-dna.php" >Extinct tortoise yields oldest tropical DNA</a></h2>
# 		<!--
# 		<h2><a href="/articles/2017/02/extinct-tortoise-yields-oldest-tropical-dna.html">Extinct tortoise yields oldest tropical DNA</a></h2>
# 		-->
#
# 		<!--
# 		<p>Extinct tortoise yields oldest tropical DNA</p>
# 		-->
#
# 		<a href="http://news.ufl.edu/articles/2017/02/extinct-tortoise-yields-oldest-tropical-dna.php" class="read-more">Read more</a>
# 		<!--
# 		<a href="/articles/
# 2017/02/extinct-tortoise-yields-oldest-tropical-dna.html" class="read-more">Read more</a>
# 		-->
# 	</div>
# 	<!--
#     <div class="category-tag"></div>
#     -->
#     <div class="category-tag">Paleontology</div>
# </div>
# 				<div class="big-stat-wrap four big-stat-img gradient-bg content-369201" style="background-image: url(/media/newsufledu/images/2017/02/lobby-square.jpg)" >
# 	<div class="big-stat-copy">
# 		<h2><a href="http://news.ufl.edu/articles/2017/02/gator-entrepreneurs-return-to-gainesville.php" >Gat
# ors return to Gainesville</a></h2>
# 		<!--
# 		<h2><a href="/articles/2017/02/gators-return-to-gainesville.html">Gators return to Gainesville</a></h2>
# 		-->
#
# 		<!--
# 		<p>Gators return to Gainesville</p>
# 		-->
#
# 		<a href="http://news.ufl.edu/articles/2017/02/gator-entrepreneurs-return-to-gainesville.php" class="read-more">Read more</a>
# 		<!--
# 		<a href="/articles/2017/02/gators-return-to-gainesville.html" class="read-more">Read more</a>
# 		-->
# 	</div>
# 	<!--
#     <div class="category-tag"></div>
#
#   -->
#     <div class="category-tag">Alumni</div>
# </div>
# 			</div>
# 		</div>
# 	</div>
# </div><div class="breaker" style="background-image: url(/media/wwwufledu/images/bg-breaker.jpg);" data-content="354081">
# 	<div class="container">
# 		<div class="row">
# 			<div class="col-sm-8 col-sm-offset-2">
#
# 				<h2>WANT TO BE A GATOR?</h2>
# 				<p>Whatever you’ve got your sights set on, that’s merely the beginning. As a Gator you’ll learn to see beyond the horizon. We measure success not in ind
# ividual achievement, but where you go from there. Because when reaching your goals is just the starting point, there’s no end to what Gators can accomplish.</p>
# 				<p><a href="http://www.admissions.ufl.edu/apply/freshman/ " class="btn btn--white">Learn More <span class="arw-right icon-svg"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span></a></p>
# 			</div>
# 		</div>
# 	</div>
# </div><div class="feature-bio-wrap hor-s
# croll-wrap" id="bio_257698" data-bio-affiliation="all">
# 	<div class="container">
# 		<div class="feature-bios">
# 			<div class="bio-wrap">
# 				<div class="bio hor-scroll-el">
# 					<div class="bio-img" style="background-image: url();"></div>
# 					<div class="copy-wrap">
# 						<h2></h2>
# 						<h3></h3>
# 						<p></p>
# 						<span class="category-tag orange"></span>
# 						<span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></s
# pan>
# 					</div>
# 				</div>
# 				<div class="bio hor-scroll-el">
# 					<div class="bio-img" style="background-image: url();"></div>
# 					<div class="copy-wrap">
# 					    <h2></h2>
# 					    <h3></h3>
# 					    <p></p>
# 					    <span class="category-tag orange"></span>
# 					    <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# 					</div>
# 				</div>
# 				<div class="bio hor-scroll-el">
# 					<div class="bio-img"
# style="background-image: url();"></div>
# 					<div class="copy-wrap">
# 					    <h2></h2>
# 					    <h3></h3>
# 					    <p></p>
# 					    <span class="category-tag orange"></span>
# 					    <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="feature-bio-copy-wrap">
# 				<h2></h2>
# 				<h3></h3>
# 				<p></p>
# 				<span class="category-tag orange"></span>
# 				<span class=
# "btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# 			</div>
# 		</div>
# 	</div>
# </div><div class="breaker" style="background-image: url(/media/wwwufledu/images/gator_good.jpg);" data-content="253749">
# 	<div class="container">
# 		<div class="row">
# 			<div class="col-sm-8 col-sm-offset-2">
#
# 				<h2>For the Gator Good</h2>
# 				<p>The challenges facing our world are bigger than one person. One
# <br />organization. O
# ne university. The Gator Good is our
# <br />campaign to combine those efforts and solve those global problems.
# <br />Because together, our impact is greater.</p>
# 				<p><a href="http://gatorgood.com" class="btn btn--white">Learn More <span class="arw-right icon-svg"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span></a></p>
# 			</div>
# 		</div>
# 	</div>
# </div>              <div class="footer-wrap">
#
#
#                  <div class="footer-top">
#   <div class="container">
#     <div class="row">
#       <div class="col-sm-12">
#         <ul class="footer-audience-nav">
#           <li><a href="http://admissions.ufl.edu/">Apply</a></li>
#           <li><a href="http://virtualtour.ufl.edu/">Visit</a></li>
#           <li><a href="https://jobs.ufl.edu/">Jobs</a></li>
#           <li><a href="http://questions.ufl.edu/">Ask UF</a></li>
#         </ul>
#       </div>
#     </div>
#   </div>
# </div>
#
#
#           <div class="footer-bottom">
#                       <div class="container">
#                           <div class="row">
#
#                               <div class="col-md-4 col-md-push-8 footer-contact-wrap">
#                                 <a href="http://www.ufl.edu" class="footer-logo icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#florida-logo-full"></use></svg><span class="visuallyhidden">University of Florida</span></a>
#
#      <ul class="social-nav">
#   <li><a href="http://www.facebook.com/uflorida/" class="btn-circle icon-svg icon-facebook"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#facebook"></use></svg><span class="visuallyhidden">Facebook</span></a></li>
#   <li><a href="https://twitter.com/UF/" class="btn-circle icon-svg icon-twitter"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#twitter"></use></s
# vg><span class="visuallyhidden">Twitter</span></a></li>
#   <li><a href="https://instagram.com/uflorida/" class="btn-circle icon-svg icon-instagram"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#instagram"></use></svg><span class="visuallyhidden">Instagram</span></a></li>
#   <li><a href="http://www.youtube.com/user/universityofflorida/" class="btn-circle icon-svg icon-youtube"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/
# templates/uf2015/img/spritemap.svg#youtube"></use></svg><span class="visuallyhidden">YouTube</span></a></li>
# </ul>
#                                   <p class="address">University of Florida<br>Gainesville, FL 32611<br>(352) 392-3261<br><a href="http://assistive.usablenet.com/tt/referrer">Text-only Version</a></p>
#                               </div>
#
#                               <div class="col-md-8 col-md-pull-4">
#   <div class="row">
#     <div class="col-md-4 col-sm-4 footer-menu">
#
#     <h2>Resources <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
#       <ul>
# <li><a href="https://one.uf.edu/">ONE.UF</a></li>
# <li><a href="https://webmail.ufl.edu/">Webmail</a></li>
# <li><a href="https://my.ufl.edu/ps/signon.html">myUFL</a></li>
# <li><a href="https://lss.at.ufl.edu/">e-Learning</a></li>
# <li><a href="https://directory.ufl.edu/">Directory</a></li>
# </ul>
#     </div>
#
#  <div class="col-md-4 col-sm-4 footer-menu">
#       <h2>Campus <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
#       <ul>
# <li><a href="http://ufweather.org/">Weather</a></li>
# <li><a href="http://campusmap.ufl.edu/">Campus Map</a></li>
# <li><a href="http://virtualtour.ufl.edu/">Student Tours</a></li>
# <li><a href="https://catalog.ufl.edu/ugrad/current/Pages/dates-and-deadlines.aspx">Aca
# demic Calendar</a></li>
# <li><a href="http://calendar.ufl.edu/">Events</a></li>
# <li><a href="http://zika.ufl.edu">Zika Update</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; statements.ufl.edu" href="http://statements.ufl.edu">Statements</a></li>
# </ul>
#     </div>
#     <div class="col-md-4 col-sm-4 footer-menu">
#       <h2>Website <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
#
#     <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Websites" href="/websites/">Website Listing</a></li>
# <li><a href="http://accessibility.ufl.edu/">Accessibility</a></li>
# <li><a href="http://privacy.ufl.edu/privacystatement.html">Privacy Policy</a></li>
# <li><a href="http://regulations.ufl.edu/">Regulations</a></li>
# </ul>
#     </div>
#   </div>
# </div>
#
#                           </div>
#                       </div>
#                   </div>
#
#               <
# /div>
# 			</div>
# 		</div>
# 	</div>
#   <script>
# var statsjson = '/stats/index.json';
# var biosjson = '/biographies/index.json';
# </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/velocity/1.2.2/velocity.min.js"></script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/velocity/1.2.2/velocity.ui.min.js"></script>
#   <script type="text/javascript" src="/media/templates/uf2015/js/plugins.js"></script>
#
#   <script type="text/javascript" src="/media/templates/uf2015/js/scripts.js"></script>
#
#
#
# <script>
# $(document).ready(function() {
#
#
# });
# </script>
# <script>
# $(document).ready(function() {
# 	displayUFAlert();
#
# 	$('a').click(function() {
# 		var href = $(this).attr('href');
# 		if (href.match(/^http/) && !href.match(document.domain)) {
# 			ga('send', 'event', 'Outbound Links', 'Click', href);
# 		}
# 		if (href.match(/\.(doc|docx|pdf|ppt|pptx|xls|xlsx|zip)$/)) {
# 			ga('send', 'event', 'Downloads'
# , 'Click', href);
# 		}
# 	});
# 	$('.aux-nav a').click(function() {
# 		ga('send', 'event', 'Auxiliary Navigation', 'Click', $(this).attr('href'));
# 	});
# 	$('.main-menu-wrap a').click(function() {
# 		ga('send', 'event', 'Primary Navigation', 'Click', $(this).attr('href'));
# 	});
# 	$('.featured-story a.read-more').click(function() {
# 		ga('send', 'event', 'Featured Story', 'Click', $(this).attr('href'));
# 	});
# 	$('.big-stat-wrap h2 a').click(function() {
# 		ga('send', 'event', 'Secondary Story', 'Click', $(th
# is).attr('href'));
# 	});
# 	$('.footer-menu a').click(function() {
# 		ga('send', 'event', 'Footer Menu', 'Click', $(this).attr('href'));
# 	});
# 	$('.home .featured-story.article-271180 .category-tag').text('Inauguration');
# 	$('.home .big-stat-wrap.content-271968 .category-tag').text('Commencement');
# });
# </script>
#
# <style>
# .embed-responsive {
#     position: relative;
#     display: block;
#     height: 0;
#     padding: 0;
#     overflow: hidden;
# }
# .embed-responsive .embed-responsive-item, .embed-responsi
# ve iframe, .embed-responsive embed, .embed-responsive object, .embed-responsive video {
#     position: absolute;
#     top: 0;
#     left: 0;
#     bottom: 0;
#     height: 100%;
#     width: 100%;
#     border: 0;
# }
# .embed-responsive.embed-responsive-16by9 {
#     padding-bottom: 56.25%}
# .embed-responsive.embed-responsive-4by3 {
#     padding-bottom: 75%}
# </style>
#
# <!-- Host: 128.227.74.198 -->
# <!-- 11e06c425fe89aaad9f91d050f0d192a5e5c4946 -->
#
#
# </body>
# </html>

# %% [markdown]
# ## Use the urllib library

# %%
import urllib

# %%
fhand = urllib.urlopen('http://www.ufl.edu/index.html')

for line in fhand:
    print line.strip()
# Out:
# <!DOCTYPE html>
# <html lang="en" class="no-js">
# <head>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width,initial-scale=1">
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <title>University of Florida</title>
# <link rel="stylesheet" href="/media/templates/uf2015/css/style.css">
#
#
#
# <link rel="icon" href="/media/templates/uf2015/img/favicon.ico" >
# <link rel="apple-touch-icon" href="/media/templates/uf2015/img/favicon-180.png">
# <meta name="msapplication-TileColor" content="#00529b">
# <meta name="msapplication-TileImage" content="/media/templates/uf2015/img/favicon-144.png">
# <script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create', 'UA-3703196-1', 'auto');ga('send', 'pageview');</script>
# </head>
#
# <body class="loading home">
# <a href="#main" id="skip-link" class="visuallyhidden focusable">Skip to main content</a>
# <div class="header">
# <a href="http://www.ufl.edu/" class="logo"><img src="/media/templates/uf2015/img/logo-uf.svg"
# alt="logo-uf" style="width : -1px; height : -1px;     "
# class="" /></a>
#
# <div class="menu-wrap">
# <div class="main-menu-wrap">
#
# <ul>
# <li>
# <a href="/about/" class="main-menu-link"><span>About</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/about.jpg" alt="About Image" class="img-full">
# </div>
# <ul>
# <li><a href="/about/administration/">Administration</a></li>
# <li><a href="/about/maps-directions/">Maps &amp; Directions</a></li>
# <li><a href="/about/campus-tours/">Campus Tours</a></li>
# </ul>
# <ul>
# <li><a href="/about/university-facts/">University Facts</a></li>
# <li><a href="/about/history/">History</a></li>
# <li><a href="/about/offices-services/">Offices &amp; Services</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/academics/" class="main-menu-link"><span>Academics</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/academics.jpg" alt="Academics Image" class="img-full">
# </div>
# <ul>
# <li><a href="/academics/colleges/">Colleges</a></li>
# <li><a href="/academics/programs/">Programs</a></li>
# <li><a href="/academics/courses/">Courses</a></li>
# <li><a href="/academics/online-learning/">Online Learning</a></li>
# </ul>
# <ul>
# <li><a href="https://catalog.ufl.edu/ugrad/current/Pages/certificates.aspx">Certificates</a></li>
# <li><a href="http://pd.dce.ufl.edu/program-finder">Continuing Education</a></li>
# <li><a href="/academics/libraries/">Libraries</a></li>
# <li><a href="/academics/resources/">Resources</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/admissions/" class="main-menu-link"><span>Admissions</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/admissions.jpg" alt="Admissions Image" class="img-full">
# </div>
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Undergraduate" href="/admissions/undergraduate/">Undergraduate</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Graduate" href="/admissions/graduate/">Graduate</a></li>
# <li><a href="http://www.admissions.ufl.edu/prospectiveinternational.html">International</a></li>
# </ul>
# <ul>
# <li><a href="http://www.ufl.edu/academics/online-learning/">Online Learning</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Admissions &raquo; Professional" href="/admissions/professional/">Professional</a></li>
# <li><a href="http://www.sfa.ufl.edu/">Financial Aid</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/student-life/" class="main-menu-link"><span>Student Life</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/campuslife.jpg" alt="Student Life Image" class="img-full">
# </div>
# <ul>
# <li><a href="/student-life/arts/">Arts</a></li>
# <li><a href="/student-life/recreation-fitness/">Recreation &amp; Fitness</a></li>
# <li><a href="/student-life/cultural-opportunities/">Cultural Opportunities</a></li>
# <li><a href="/student-life/involvement/">Involvement</a></li>
# </ul>
# <ul>
# <li><a href="/student-life/health-safety/">Health &amp; Safety</a></li>
# <li><a href="/student-life/career-exploration/">Career Exploration</a></li>
# <li><a href="/student-life/housing/">Housing</a></li>
# <li><a href="/student-life/success-services/">Success Services</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/research/" class="main-menu-link"><span>Research</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/research.jpg" alt="Research Image" class="img-full">
# </div>
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Centers &amp; Institutes" href="/research/centers-institutes/">Centers &amp; Institutes</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Undergraduate Research" href="/research/undergraduate-research/">Undergrad Research</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Graduate Research" href="/research/graduate-research/">Graduate Research</a></li>
# <li><a title="Office of Research" href="http://research.ufl.edu/">Office of Research</a></li>
# </ul>
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Research &raquo; Technology Licensing" href="/research/technology-licensing/">Technology Licensing</a></li>
# <li><a href="http://research.ufl.edu/faculty-and-staff/finding-funding.html">Research Funding</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/athletics/" class="main-menu-link"><span>Athletics</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/althletics.jpg" alt="Athletics Image" class="img-full">
# </div>
# <ul>
# <li><a href="http://www.floridagators.com">Florida Gators</a></li>
# <li><a href="http://floridagators.com/calendar.aspx">Schedule</a></li>
# </ul>
# <ul>
# <li><a href="http://floridagators.com/sports/2015/12/10/_tickets_.aspx">Tickets</a></li>
# <li><a href="http://floridagators.com/facilities/">Facilities</a></li>
# </ul>
# </div>
# </li><li>
# <a href="/alumni/" class="main-menu-link"><span>Alumni</span> <span class="icon-svg icon-caret"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></a>
# <div class="dropdown">
# <div class="col-md-4">
# <img src="/media/wwwufledu/images/nav/alumni.jpg" alt="Alumni Image" class="img-full">
# </div>
# <ul>
# <li><a href="http://www.ufalumni.ufl.edu">Alumni Association</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/network/gatorclubs">Gator Clubs&reg;</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/membership/join-the-ufaa">Membership</a></li>
# <li><a href="http://connect.ufalumni.ufl.edu/events/signature-events">Reunions</a></li>
# </ul>
# <ul>
# <li><a href="https://www.uff.ufl.edu/">Giving</a></li>
# <li><a href="/about/maps-directions/">Maps &amp; Directions</a></li>
# <li><a href="http://virtualtour.ufl.edu/">Virtual Tour</a></li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <div class="aux-menu-wrap">
# <ul class="aux-nav">
# <li><a href="http://news.ufl.edu">News</a></li>
# <li><a href="http://calendar.ufl.edu">Calendar</a></li>
# <li><a href="/about/offices-services/">Offices &amp; Services</a></li>
# <li><a href="https://directory.ufl.edu">Directory</a></li>
# <li><a href="http://uff.ufl.edu/Giving/WhyGive.asp">Giving</a></li>
# <li><a href="http://ufhealth.org">UF Health</a></li>
# <li><a href="http://ifas.ufl.edu">UF/IFAS</a></li>
# <li><a href="http://assistive.usablenet.com/tt/referrer">Text-only</a></li>
# </ul>
# <div class="audience-nav-wrap"><a href="#" class="cur-audience">Welcome to UF</a><span class="arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-down"></use></svg></span><ul>
# <li><a href="/students/">Current Students</a></li>
# <li><a href="/visitors/">Family &amp; Visitors</a></li>
# <li><a href="/staff/">Faculty &amp; Staff</a></li>
# </ul></div>
# </div>
# <a href="#" class="btn-show-aux">
# <span class="icon-svg icon-menu">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#menu"></use>
# </svg>
# </span>
# <span class="icon-svg icon-close">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#close"></use>
# </svg>
# </span>
# </a>
# <form action="https://search.ufl.edu/search" method="get" class="search-wrap">
# <input type="hidden" name="source" value="web">
#
# <label for="query_desktop" class="visuallyhidden">Search UF</label>
# <input type="text" id="query_desktop" name="query">
# <label for="submit_desktop" class="visuallyhidden">Submit</label>
# <button type="submit" id="submit_desktop" name="submit" class="btn-search">
# <span class="icon-svg">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#search"></use>
# </svg>
# </span>
# </button>
# </form>
# </div>
#
# <div class="mobile-dropdown-wrap"></div>
#
# <form action="https://search.ufl.edu/search" method="get" class="search-wrap mobile">
# <input type="hidden" name="source" value="web">
#
# <label for="query_mobile" class="visuallyhidden">Search UF</label>
# <input type="text" id="query_mobile" name="query">
# <label for="submit_mobile" class="visuallyhidden">Submit</label>
# <button type="submit" id="submit_mobile" class="btn-search">
# <span class="icon-svg">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#search"></use>
# </svg>
# </span>
# </button>
# </form>
#
# <a href="#" class="btn-menu">
# <span class="icon-svg icon-menu">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#menu"></use>
# </svg>
# </span>
# <span class="icon-svg icon-close">
# <svg>
# <use xlink:href="/media/templates/uf2015/img/spritemap.svg#close"></use>
# </svg>
# </span>
# </a>
# </div>
#
# <div id="main">
# <div class="home-section">
# <div class="homepage-wrapper"><div class="featured-story-wrap">
# <div class="featured-story-img-wrap">
# <div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2017/02/Bat-Banner---Homepage.gif)"></div>
# <div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2017/02/theinstitutes_crop.jpg)"></div>
# <div class="featured-story-img" style="background-image:url(/media/newsufledu/images/2017/02/fanara-hero.jpg)"></div>
#
# </div>
# </div>
# <div class="homepage-stat-wrap">
# <div class="container">
# <div class="row">
# <div class="col-sm-12">
# <div class="featured-story-content-wrap-wrap">
# <div class="featured-story-content-wrap col-md-6 col-md-offset-1">
# <div class="featured-story article-370148">
# <h2>UF’s bat village adds new barn <a href="https://ufnews.atavist.com/echo-relocation" class="read-more">Read more</a></h2>
#
# <!--
# <h2>UF’s bat village adds new barn <a href="/articles/2017/02/bat-village-primary-with-gif-banner.html" class="read-more">Read more</a></h2>
# -->
#
# <!--
# <div class="category-tag"></div>
# -->
# <div class="category-tag">Campus wildlife</div>
# </div><div class="featured-story article-369190">
# <h2>Revitalizing our roots <a href="https://social.shorthand.com/UFNews/3ycMiApTq6/revitalizing-our-roots" class="read-more">Read more</a></h2>
#
# <!--
# <h2>Revitalizing our roots <a href="/articles/2017/02/the-institutes-primary-from-shorthand-story.html" class="read-more">Read more</a></h2>
# -->
#
#
# <div class="category-tag">Campus Life</div>
#
#
# </div><div class="featured-story article-367971">
# <h2>This MythBuster breaks stereotypes, too <a href="http://news.ufl.edu/articles/2017/02/mythbusters-contestant-brings-shows-lessons-to-water-treatment-work-.php" class="read-more">Read more</a></h2>
#
# <!--
# <h2>This MythBuster breaks stereotypes, too <a href="/articles/2017/02/this-mythbuster-breaks-stereotypes-too.html" class="read-more">Read more</a></h2>
# -->
#
# <!--
# <div class="category-tag"></div>
# -->
# <div class="category-tag">Gators in the News</div>
# </div>
# </div>
# </div>
#
# <div class="stat-wrap one in-right randomized" data-position="one">
# <div class="stat">
# <h2>70</h2>
# </div>
# <div class="info">
# <div class="info-copy">
# <p>70% of UF undergraduates secure employment or plan employment in the state of Florida.</p>
# </div>
# </div>
# </div>
# <div class="big-stat-wrap one big-stat-img gradient-bg content-369191" style="background-image: url(/media/newsufledu/images/2017/02/SoldiersSquare.jpg)" >
# <div class="big-stat-copy">
# <h2><a href="http://news.ufl.edu/articles/2017/02/university-of-florida-partners-in-new-manufacturing-usa-institute.php" >Developing bones that won’t be rejected and more</a></h2>
# <!--
# <h2><a href="/articles/2017/02/developing-bones-that-wont-be-rejected-and-more.html">Developing bones that won’t be rejected and more</a></h2>
# -->
#
# <!--
# <p>Developing bones that won’t be rejected and more</p>
# -->
#
# <a href="http://news.ufl.edu/articles/2017/02/university-of-florida-partners-in-new-manufacturing-usa-institute.php" class="read-more">Read more</a>
# <!--
# <a href="/articles/2017/02/developing-bones-that-wont-be-rejected-and-more.html" class="read-more">Read more</a>
# -->
# </div>
# <!--
# <div class="category-tag"></div>
# -->
# <div class="category-tag">Biofabrication</div>
# </div>
# <div class="stat-wrap two in-bottom randomized" data-position="two">
# <div class="stat">
# <h2>1,900</h2>
# </div>
# <div class="info">
# <div class="info-copy">
# <p>More than 1,900 All-America honors earned by Gator athletes.</p>
# </div>
# </div>
# </div>
# <div class="big-stat-wrap two big-stat-img gradient-bg content-365238" style="background-image: url(/media/newsufledu/images/2017/01/FuchsTurlington.PNG)" >
# <div class="big-stat-copy">
# <h2><a href="https://www.facebook.com/uflorida/videos/1158827657559258/" >President Fuchs talks with students in Turlington</a></h2>
# <!--
# <h2><a href="/articles/2017/01/social---fuchs--turlington.html">President Fuchs talks with students in Turlington</a></h2>
# -->
#
# <!--
# <p>President Fuchs talks with students in Turlington</p>
# -->
#
# <a href="https://www.facebook.com/uflorida/videos/1158827657559258/" class="read-more">Read more</a>
# <!--
# <a href="/articles/2017/01/social---fuchs--turlington.html" class="read-more">Read more</a>
# -->
# </div>
#
# <div class="category-tag">Social Media</div>
#
#
# </div>
# <div class="big-stat-wrap three big-stat-img gradient-bg content-369192" style="background-image: url(/media/newsufledu/images/2017/02/Tortoise.jpg)" >
# <div class="big-stat-copy">
# <h2><a href="http://news.ufl.edu/articles/2017/02/extinct-tortoise-yields-oldest-tropical-dna.php" >Extinct tortoise yields oldest tropical DNA</a></h2>
# <!--
# <h2><a href="/articles/2017/02/extinct-tortoise-yields-oldest-tropical-dna.html">Extinct tortoise yields oldest tropical DNA</a></h2>
# -->
#
# <!--
# <p>Extinct tortoise yields oldest tropical DNA</p>
# -->
#
# <a href="http://news.ufl.edu/articles/2017/02/extinct-tortoise-yields-oldest-tropical-dna.php" class="read-more">Read more</a>
# <!--
# <a href="/articles/2017/02/extinct-tortoise-yields-oldest-tropical-dna.html" class="read-more">Read more</a>
# -->
# </div>
# <!--
# <div class="category-tag"></div>
# -->
# <div class="category-tag">Paleontology</div>
# </div>
# <div class="big-stat-wrap four big-stat-img gradient-bg content-369201" style="background-image: url(/media/newsufledu/images/2017/02/lobby-square.jpg)" >
# <div class="big-stat-copy">
# <h2><a href="http://news.ufl.edu/articles/2017/02/gator-entrepreneurs-return-to-gainesville.php" >Gators return to Gainesville</a></h2>
# <!--
# <h2><a href="/articles/2017/02/gators-return-to-gainesville.html">Gators return to Gainesville</a></h2>
# -->
#
# <!--
# <p>Gators return to Gainesville</p>
# -->
#
# <a href="http://news.ufl.edu/articles/2017/02/gator-entrepreneurs-return-to-gainesville.php" class="read-more">Read more</a>
# <!--
# <a href="/articles/2017/02/gators-return-to-gainesville.html" class="read-more">Read more</a>
# -->
# </div>
# <!--
# <div class="category-tag"></div>
# -->
# <div class="category-tag">Alumni</div>
# </div>
# </div>
# </div>
# </div>
# </div><div class="breaker" style="background-image: url(/media/wwwufledu/images/bg-breaker.jpg);" data-content="354081">
# <div class="container">
# <div class="row">
# <div class="col-sm-8 col-sm-offset-2">
#
# <h2>WANT TO BE A GATOR?</h2>
# <p>Whatever you’ve got your sights set on, that’s merely the beginning. As a Gator you’ll learn to see beyond the horizon. We measure success not in individual achievement, but where you go from there. Because when reaching your goals is just the starting point, there’s no end to what Gators can accomplish.</p>
# <p><a href="http://www.admissions.ufl.edu/apply/freshman/ " class="btn btn--white">Learn More <span class="arw-right icon-svg"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span></a></p>
# </div>
# </div>
# </div>
# </div><div class="feature-bio-wrap hor-scroll-wrap" id="bio_257698" data-bio-affiliation="all">
# <div class="container">
# <div class="feature-bios">
# <div class="bio-wrap">
# <div class="bio hor-scroll-el">
# <div class="bio-img" style="background-image: url();"></div>
# <div class="copy-wrap">
# <h2></h2>
# <h3></h3>
# <p></p>
# <span class="category-tag orange"></span>
# <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# </div>
# </div>
# <div class="bio hor-scroll-el">
# <div class="bio-img" style="background-image: url();"></div>
# <div class="copy-wrap">
# <h2></h2>
# <h3></h3>
# <p></p>
# <span class="category-tag orange"></span>
# <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# </div>
# </div>
# <div class="bio hor-scroll-el">
# <div class="bio-img" style="background-image: url();"></div>
# <div class="copy-wrap">
# <h2></h2>
# <h3></h3>
# <p></p>
# <span class="category-tag orange"></span>
# <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# </div>
# </div>
# </div>
# <div class="feature-bio-copy-wrap">
# <h2></h2>
# <h3></h3>
# <p></p>
# <span class="category-tag orange"></span>
# <span class="btn-circle arw-right icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span>
# </div>
# </div>
# </div>
# </div><div class="breaker" style="background-image: url(/media/wwwufledu/images/gator_good.jpg);" data-content="253749">
# <div class="container">
# <div class="row">
# <div class="col-sm-8 col-sm-offset-2">
#
# <h2>For the Gator Good</h2>
# <p>The challenges facing our world are bigger than one person. One
# <br />organization. One university. The Gator Good is our
# <br />campaign to combine those efforts and solve those global problems.
# <br />Because together, our impact is greater.</p>
# <p><a href="http://gatorgood.com" class="btn btn--white">Learn More <span class="arw-right icon-svg"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#arw-right"></use></svg></span></a></p>
# </div>
# </div>
# </div>
# </div>              <div class="footer-wrap">
#
# <div class="footer-top">
# <div class="container">
# <div class="row">
# <div class="col-sm-12">
# <ul class="footer-audience-nav">
# <li><a href="http://admissions.ufl.edu/">Apply</a></li>
# <li><a href="http://virtualtour.ufl.edu/">Visit</a></li>
# <li><a href="https://jobs.ufl.edu/">Jobs</a></li>
# <li><a href="http://questions.ufl.edu/">Ask UF</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
#
# <div class="footer-bottom">
# <div class="container">
# <div class="row">
#
# <div class="col-md-4 col-md-push-8 footer-contact-wrap">
# <a href="http://www.ufl.edu" class="footer-logo icon-svg"><svg><use xlink:href="/media/templates/uf2015/img/spritemap.svg#florida-logo-full"></use></svg><span class="visuallyhidden">University of Florida</span></a>
# <ul class="social-nav">
# <li><a href="http://www.facebook.com/uflorida/" class="btn-circle icon-svg icon-facebook"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#facebook"></use></svg><span class="visuallyhidden">Facebook</span></a></li>
# <li><a href="https://twitter.com/UF/" class="btn-circle icon-svg icon-twitter"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#twitter"></use></svg><span class="visuallyhidden">Twitter</span></a></li>
# <li><a href="https://instagram.com/uflorida/" class="btn-circle icon-svg icon-instagram"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#instagram"></use></svg><span class="visuallyhidden">Instagram</span></a></li>
# <li><a href="http://www.youtube.com/user/universityofflorida/" class="btn-circle icon-svg icon-youtube"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#youtube"></use></svg><span class="visuallyhidden">YouTube</span></a></li>
# </ul>
# <p class="address">University of Florida<br>Gainesville, FL 32611<br>(352) 392-3261<br><a href="http://assistive.usablenet.com/tt/referrer">Text-only Version</a></p>
# </div>
#
# <div class="col-md-8 col-md-pull-4">
# <div class="row">
# <div class="col-md-4 col-sm-4 footer-menu">
# <h2>Resources <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
# <ul>
# <li><a href="https://one.uf.edu/">ONE.UF</a></li>
# <li><a href="https://webmail.ufl.edu/">Webmail</a></li>
# <li><a href="https://my.ufl.edu/ps/signon.html">myUFL</a></li>
# <li><a href="https://lss.at.ufl.edu/">e-Learning</a></li>
# <li><a href="https://directory.ufl.edu/">Directory</a></li>
# </ul>
# </div>
# <div class="col-md-4 col-sm-4 footer-menu">
# <h2>Campus <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
# <ul>
# <li><a href="http://ufweather.org/">Weather</a></li>
# <li><a href="http://campusmap.ufl.edu/">Campus Map</a></li>
# <li><a href="http://virtualtour.ufl.edu/">Student Tours</a></li>
# <li><a href="https://catalog.ufl.edu/ugrad/current/Pages/dates-and-deadlines.aspx">Academic Calendar</a></li>
# <li><a href="http://calendar.ufl.edu/">Events</a></li>
# <li><a href="http://zika.ufl.edu">Zika Update</a></li>
# <li><a title="Home &raquo; ufl.edu &raquo; statements.ufl.edu" href="http://statements.ufl.edu">Statements</a></li>
# </ul>
# </div>
# <div class="col-md-4 col-sm-4 footer-menu">
# <h2>Website <span class="icon-svg icon-caret"><svg><use xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="/media/templates/uf2015/img/spritemap.svg#caret"></use></svg></span></h2>
# <ul>
# <li><a title="Home &raquo; ufl.edu &raquo; www.ufl.edu &raquo; Websites" href="/websites/">Website Listing</a></li>
# <li><a href="http://accessibility.ufl.edu/">Accessibility</a></li>
# <li><a href="http://privacy.ufl.edu/privacystatement.html">Privacy Policy</a></li>
# <li><a href="http://regulations.ufl.edu/">Regulations</a></li>
# </ul>
# </div>
# </div>
# </div>
#
# </div>
# </div>
# </div>
#
# </div>
# </div>
# </div>
# </div>
# <script>
# var statsjson = '/stats/index.json';
# var biosjson = '/biographies/index.json';
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/velocity/1.2.2/velocity.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/velocity/1.2.2/velocity.ui.min.js"></script>
# <script type="text/javascript" src="/media/templates/uf2015/js/plugins.js"></script>
# <script type="text/javascript" src="/media/templates/uf2015/js/scripts.js"></script>
#
#
#
# <script>
# $(document).ready(function() {
#
#
# });
# </script>
# <script>
# $(document).ready(function() {
# displayUFAlert();
#
# $('a').click(function() {
# var href = $(this).attr('href');
# if (href.match(/^http/) && !href.match(document.domain)) {
# ga('send', 'event', 'Outbound Links', 'Click', href);
# }
# if (href.match(/\.(doc|docx|pdf|ppt|pptx|xls|xlsx|zip)$/)) {
# ga('send', 'event', 'Downloads', 'Click', href);
# }
# });
# $('.aux-nav a').click(function() {
# ga('send', 'event', 'Auxiliary Navigation', 'Click', $(this).attr('href'));
# });
# $('.main-menu-wrap a').click(function() {
# ga('send', 'event', 'Primary Navigation', 'Click', $(this).attr('href'));
# });
# $('.featured-story a.read-more').click(function() {
# ga('send', 'event', 'Featured Story', 'Click', $(this).attr('href'));
# });
# $('.big-stat-wrap h2 a').click(function() {
# ga('send', 'event', 'Secondary Story', 'Click', $(this).attr('href'));
# });
# $('.footer-menu a').click(function() {
# ga('send', 'event', 'Footer Menu', 'Click', $(this).attr('href'));
# });
# $('.home .featured-story.article-271180 .category-tag').text('Inauguration');
# $('.home .big-stat-wrap.content-271968 .category-tag').text('Commencement');
# });
# </script>
#
# <style>
# .embed-responsive {
# position: relative;
# display: block;
# height: 0;
# padding: 0;
# overflow: hidden;
# }
# .embed-responsive .embed-responsive-item, .embed-responsive iframe, .embed-responsive embed, .embed-responsive object, .embed-responsive video {
# position: absolute;
# top: 0;
# left: 0;
# bottom: 0;
# height: 100%;
# width: 100%;
# border: 0;
# }
# .embed-responsive.embed-responsive-16by9 {
# padding-bottom: 56.25%}
# .embed-responsive.embed-responsive-4by3 {
# padding-bottom: 75%}
# </style>
#
# <!-- Host: 128.227.74.198 -->
# <!-- 11e06c425fe89aaad9f91d050f0d192a5e5c4946 -->
#
#
# </body>
# </html>

# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## Get all links from a web page

# %%
import urllib
from bs4 import *

# %%
html = urllib.urlopen('http://www.ufl.edu/index.html').read()
soup = BeautifulSoup(html,"html5lib") #parsed html

# %%
tags = soup('a') #retrieve a list of the anchor tags
for tag in tags:
    print tag.get('href',None) #get the value of attribute 'href'
# Out:
# #main
# http://www.ufl.edu/
# /about/
# /about/administration/
# /about/maps-directions/
# /about/campus-tours/
# /about/university-facts/
# /about/history/
# /about/offices-services/
# /academics/
# /academics/colleges/
# /academics/programs/
# /academics/courses/
# /academics/online-learning/
# https://catalog.ufl.edu/ugrad/current/Pages/certificates.aspx
# http://pd.dce.ufl.edu/program-finder
# /academics/libraries/
# /academics/resources/
# /admissions/
# /admissions/undergraduate/
# /admissions/graduate/
# http://www.admissions.ufl.edu/prospectiveinternational.html
# http://www.ufl.edu/academics/online-learning/
# /admissions/professional/
# http://www.sfa.ufl.edu/
# /student-life/
# /student-life/arts/
# /student-life/recreation-fitness/
# /student-life/cultural-opportunities/
# /student-life/involvement/
# /student-life/health-safety/
# /student-life/career-exploration/
# /student-life/housing/
# /student-life/success-services/
# /research/
# /research/centers-institutes/
# /research/undergraduate-research/
# /research/graduate-research/
# http://research.ufl.edu/
# /research/technology-licensing/
# http://research.ufl.edu/faculty-and-staff/finding-funding.html
# /athletics/
# http://www.floridagators.com
# http://floridagators.com/calendar.aspx
# http://floridagators.com/sports/2015/12/10/_tickets_.aspx
# http://floridagators.com/facilities/
# /alumni/
# http://www.ufalumni.ufl.edu
# http://connect.ufalumni.ufl.edu/network/gatorclubs
# http://connect.ufalumni.ufl.edu/membership/join-the-ufaa
# http://connect.ufalumni.ufl.edu/events/signature-events
# https://www.uff.ufl.edu/
# /about/maps-directions/
# http://virtualtour.ufl.edu/
# http://news.ufl.edu
# http://calendar.ufl.edu
# /about/offices-services/
# https://directory.ufl.edu
# http://uff.ufl.edu/Giving/WhyGive.asp
# http://ufhealth.org
# http://ifas.ufl.edu
# http://assistive.usablenet.com/tt/referrer
# #
# /students/
# /visitors/
# /staff/
# #
# #
# https://ufnews.atavist.com/echo-relocation
# https://social.shorthand.com/UFNews/3ycMiApTq6/revitalizing-our-roots
# http://news.ufl.edu/articles/2017/02/mythbusters-contestant-brings-shows-lessons-to-water-treatment-work-.php
# http://news.ufl.edu/articles/2017/02/university-of-florida-partners-in-new-manufacturing-usa-institute.php
# http://news.ufl.edu/articles/2017/02/university-of-florida-partners-in-new-manufacturing-usa-institute.php
# https://www.facebook.com/uflorida/videos/1158827657559258/
# https://www.facebook.com/uflorida/videos/1158827657559258/
# http://news.ufl.edu/articles/2017/02/extinct-tortoise-yields-oldest-tropical-dna.php
# http://news.ufl.edu/articles/2017/02/extinct-tortoise-yields-oldest-tropical-dna.php
# http://news.ufl.edu/articles/2017/02/gator-entrepreneurs-return-to-gainesville.php
# http://news.ufl.edu/articles/2017/02/gator-entrepreneurs-return-to-gainesville.php
# http://www.admissions.ufl.edu/apply/freshman/
# http://gatorgood.com
# http://admissions.ufl.edu/
# http://virtualtour.ufl.edu/
# https://jobs.ufl.edu/
# http://questions.ufl.edu/
# http://www.ufl.edu
# http://www.facebook.com/uflorida/
# https://twitter.com/UF/
# https://instagram.com/uflorida/
# http://www.youtube.com/user/universityofflorida/
# http://assistive.usablenet.com/tt/referrer
# https://one.uf.edu/
# https://webmail.ufl.edu/
# https://my.ufl.edu/ps/signon.html
# https://lss.at.ufl.edu/
# https://directory.ufl.edu/
# http://ufweather.org/
# http://campusmap.ufl.edu/
# http://virtualtour.ufl.edu/
# https://catalog.ufl.edu/ugrad/current/Pages/dates-and-deadlines.aspx
# http://calendar.ufl.edu/
# http://zika.ufl.edu
# http://statements.ufl.edu
# /websites/
# http://accessibility.ufl.edu/
# http://privacy.ufl.edu/privacystatement.html
# http://regulations.ufl.edu/

# %% [markdown]
# # API

# %% [markdown]
# ## Google Geocoding API

# %%
import urllib
import json

# %%
serviceurl = 'http://maps.googleapis.com/maps/api/geocode/json?'
address = 'Gainesville FL'

# %%
url = serviceurl + urllib.urlencode({'sensor':'false','address':address})
print 'Retrieving', url
uh = urllib.urlopen(url)
data = uh.read()
print 'Retrieved', len(data), 'characters'
# Out:
# Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Gainesville+FL
# Retrieved 1756 characters

# %%
try: js = json.loads(str(data))
except: js = None
if 'status' not in js or js['status'] != 'OK':
    print 'Fail to retrieve'
    print data
print json.dumps(js, indent=4)
# Out:
# {
#     "status": "OK",
#     "results": [
#         {
#             "geometry": {
#                 "location_type": "APPROXIMATE",
#                 "bounds": {
#                     "northeast": {
#                         "lat": 29.770553,
#                         "lng": -82.218976
#                     },
#                     "southwest": {
#                         "lat": 29.601988,
#                         "lng": -82.42051599999999
#                     }
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.770553,
#                         "lng": -82.218976
#                     },
#                     "southwest": {
#                         "lat": 29.601988,
#                         "lng": -82.42051599999999
#                     }
#                 },
#                 "location": {
#                     "lat": 29.6516344,
#                     "lng": -82.32482619999999
#                 }
#             },
#             "address_components": [
#                 {
#                     "long_name": "Gainesville",
#                     "types": [
#                         "locality",
#                         "political"
#                     ],
#                     "short_name": "Gainesville"
#                 },
#                 {
#                     "long_name": "Alachua County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ],
#                     "short_name": "Alachua County"
#                 },
#                 {
#                     "long_name": "Florida",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ],
#                     "short_name": "FL"
#                 },
#                 {
#                     "long_name": "United States",
#                     "types": [
#                         "country",
#                         "political"
#                     ],
#                     "short_name": "US"
#                 }
#             ],
#             "place_id": "ChIJKyy_aSEg5ogRlo0QKF1554A",
#             "formatted_address": "Gainesville, FL, USA",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ]
# }

# %%
lat = js['results'][0]['geometry']['location']['lat']
lng = js['results'][0]['geometry']['location']['lng']
print 'lat',lat,'lng',lng
# Out:
# lat 29.6516344 lng -82.3248262

# %%
location = js['results'][0]['formatted_address']
print location
# Out:
# Gainesville, FL, USA

# %% [markdown]
# ## Twitter API

# %%
import urllib
from oauth import oauth

# %%
secrets = {
    "consumer_key" : "j...u",
    "consumer_secret" : "u...d",
    "token_key" : "8...L",
    "token_secret" : "f...V"
}
apiurl = 'https://api.twitter.com/1.1/statuses/user_timeline.json'
parameters = {'screen_name':'realDonaldTrump','count':'1'}

# %%
def augment(secrets,url,parameters):
    consumer = oauth.OAuthConsumer(secrets['consumer_key'],secrets['consumer_secret'])
    token = oauth.OAuthToken(secrets['token_key'],secrets['token_secret'])
    oauth_request = oauth.OAuthRequest.from_consumer_and_token(consumer,token=token, http_method='GET',http_url=url,parameters=parameters)
    oauth_request.sign_request(oauth.OAuthSignatureMethod_HMAC_SHA1(),consumer,token)
    return oauth_request.to_url()

# %%
url = augment(secrets,apiurl,parameters)

# %%
print url
# Out:
# https://api.twitter.com/1.1/statuses/user_timeline.json?count=1&oauth_version=1.0&oauth_token=835522116502044673-s1D23cl12aj4mV7zrIoR9MR6xhFsrNL&screen_name=realDonaldTrump&oauth_nonce=20347394&oauth_timestamp=1488221452&oauth_signature=xsBDlcTMVlK0kfQieVftG7bR9GM%3D&oauth_consumer_key=jrzbw5dGqKVy2gYDZBTifeOtu&oauth_signature_method=HMAC-SHA1

# %%
connection = urllib.urlopen(url)

# %%
data = connection.read()

# %%
print data
# Out:
# [{"created_at":"Mon Feb 27 17:06:23 +0000 2017","id":836261209540288513,"id_str":"836261209540288513","text":"Great meeting with CEOs of leading U.S. health insurance companies who provide great healthcare to the American peo\u2026 https:\/\/t.co\/60jigi6ffS","truncated":true,"entities":{"hashtags":[],"symbols":[],"user_mentions":[],"urls":[{"url":"https:\/\/t.co\/60jigi6ffS","expanded_url":"https:\/\/twitter.com\/i\/web\/status\/836261209540288513","display_url":"twitter.com\/i\/web\/status\/8\u2026","indices":[117,140]}]},"source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":25073877,"id_str":"25073877","name":"Donald J. Trump","screen_name":"realDonaldTrump","location":"Washington, DC","description":"45th President of the United States of America","url":null,"entities":{"description":{"urls":[]}},"protected":false,"followers_count":25694161,"friends_count":43,"listed_count":65318,"created_at":"Wed Mar 18 13:46:38 +0000 2009","favourites_count":45,"utc_offset":-18000,"time_zone":"Eastern Time (US & Canada)","geo_enabled":true,"verified":true,"statuses_count":34544,"lang":"en","contributors_enabled":false,"is_translator":false,"is_translation_enabled":true,"profile_background_color":"6D5C18","profile_background_image_url":"http:\/\/pbs.twimg.com\/profile_background_images\/530021613\/trump_scotland__43_of_70_cc.jpg","profile_background_image_url_https":"https:\/\/pbs.twimg.com\/profile_background_images\/530021613\/trump_scotland__43_of_70_cc.jpg","profile_background_tile":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1980294624\/DJT_Headshot_V2_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1980294624\/DJT_Headshot_V2_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/25073877\/1485301108","profile_link_color":"0D5B73","profile_sidebar_border_color":"BDDCAD","profile_sidebar_fill_color":"C5CEC0","profile_text_color":"333333","profile_use_background_image":true,"has_extended_profile":false,"default_profile":false,"default_profile_image":false,"following":false,"follow_request_sent":false,"notifications":false,"translator_type":"regular"},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"retweet_count":4955,"favorite_count":26177,"favorited":false,"retweeted":false,"possibly_sensitive":false,"lang":"en"}]

# %%
headers = connection.info().dict
print headers
# Out:
# {'content-length': '2593', 'x-rate-limit-reset': '1488222396', 'x-rate-limit-remaining': '899', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'x-connection-hash': '0ab4eb470af66f4345e022a2456f417c', 'x-twitter-response-tags': 'BouncerCompliant', 'cache-control': 'no-cache, no-store, must-revalidate, pre-check=0, post-check=0', 'status': '200 OK', 'content-disposition': 'attachment; filename=json.json', 'set-cookie': 'lang=en; Path=/, guest_id=v1%3A148822149657350382; Domain=.twitter.com; Path=/; Expires=Wed, 27-Feb-2019 18:51:36 UTC', 'expires': 'Tue, 31 Mar 1981 05:00:00 GMT', 'x-access-level': 'read-write', 'last-modified': 'Mon, 27 Feb 2017 18:51:36 GMT', 'pragma': 'no-cache', 'date': 'Mon, 27 Feb 2017 18:51:36 GMT', 'x-rate-limit-limit': '900', 'x-response-time': '67', 'x-transaction': '00c695ad00005f9b', 'strict-transport-security': 'max-age=631138519', 'server': 'tsa_b', 'x-frame-options': 'SAMEORIGIN', 'content-type': 'application/json;charset=utf-8'}
